# %% [markdown]
# # Yelp API - Lab
#
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, it's time to put those API and SQL skills to work in order to do some basic business analysis! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create a DB on AWS to store information from Yelp about businesses
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and insert the information into your DB
# * Perform pagination to retrieve troves of data!
# * Write SQL queries to answer questions about your data

# %% [markdown]
# ## Problem Introduction
#
# For this lab you will analyze the yelp data for a group of businesses to learn more about an industry. You will choose a type of business (Italian Restuarants, Nail Salons, Crossfit gyms) and a location to analyze. Then you will get data from the Yelp API, store that data in a SQL Database on AWS, and write queries to answer questions about the data.
#
#
# ### Process:
#
# 1. Read through the SQL questions and the API documentation to determine which pieces of information you need to pull from the Yelp API.
#
# 2. Create a DB schema with 2 tables. One for the businesses and one for the reviews.
#
# 3. Create code to:
#   - Perform a search of businesses using pagination
#   - Parse the API response for specific data points
#   - Insert the data into your AWS DB
#
# 4. Use the functions above in a loop that will paginate over the results to retrieve all of the results.
#
# 5. Create functions to:
#   - Retrieve the reviews data of one business
#   - Parse the reviews response for specific review data
#   - Insert the review data into the DB
#
# 6. Using SQL, query all of the business IDs. Using the 3 Python functions you've created, run your business IDs through a loop to get the reviews for each business and insert them into your DB.
#
# 7. Write SQL queries to answer the following questions about your data.
#
#
# Bonus Steps:
# - Place your helper functions in a package so that your final notebook only has the major steps listed.
# - Rewrite your business search functions to be able take an argument for the type of business you are searching for.
# - Add another group of businesses to your database.

# %% [markdown]
#
# ## SQL Questions:
#
# - Which are the 5 most reviewed businesses?
# - What is the highest rating recieved in your data set and how many businesses have that rating?
# - What percentage of businesses have a rating greater than or  4.5?
# - What percentage of businesses have a rating less than 3?
# - What is the average rating of restaurants that have a price label of one dollar sign? Two dollar signs? Three dollar signs?
# - Return the text of the reviews for the most reviewed restaurant.
# - Return the name of the business with the most recent review.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the restaurant with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the restaurant with the least reviews.

# %% [markdown]
# ## Part 1 - Understanding your data and question
#
# Lok at the question and determine what data you will need to store in your database in order to answer the questions. Start to thin about your DB schema. What tables will you want to create and what columns will you ahve for those tables.
#
# Look at the API documentation, and determine what fields of the API response you will match up with the columns you want in your DB tables.
#
#
# https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# ## Part 2 - Set up the DB
#
# Now that you are familiar with the data, create your SQL queries to create the DB and the appropriate tables.

# %% [markdown]
# ### Foriegn Keys
#
# For this project you will have two tables that you need to link using a foreign key. Below is some information about how to create a foriegn key.
#
# http://www.mysqltutorial.org/mysql-foreign-key/

# %% [markdown]
# ### Using DB:
#
# For this lab, you can either store the data on one DB or put in on both of the partners DBs. If you decide to put it on one DB, you want to make sure both partners have access to it.  To do this you want to add a user to your DB.
#
# [how to add a new user](https://howchoo.com/g/mtm3zdq2nzv/how-to-add-a-mysql-user-and-grant-privileges)

# %%
# list(range(1001,1950,50))

# %%
# list(range(1952,2950,50))

# %%
# list(range(2953,3950,50))

# %%
import pandas as pd
import requests

import json

API_KEY='sWBP_z5n8gN0817l1XcH18vpJrdxNj-Et2h_1qb7Rc86fgKR1Rb3zSmgGj1UCmJgO_9vf7H8-wraSeE_T9W5pQ6n25cxbuk4VdEu2RD7mVXfFdl2xjDsU3dQiZEoXnYx'
API_KEY1='Ur3A2QUMRv8oAUDuvBjdwsJ2w4RsFeMcDvMmW1S5WIjHGUeYNthn8gHfM8_-NYyDmp7ZNPEvv7LyDWaYALZd_Q4_H4BGnNHmOAKs0PuuKa3EuHNrtDqn371_0XwqXnYx'

headers={'Authorization':'bearer %s'% API_KEY}

headers1={'Authorization':'bearer %s'% API_KEY1}

# %%
def businessCallGET(args):
    businessEndpoint = 'https://api.yelp.com/v3/businesses/search'
    return requests.get(businessEndpoint, params=args,headers=headers)

# %%
#from page 1 to 1000 
offset=list(range(0,1000,50))
business_data=[]
for i in offset:
    b_params={'term':'pizza','location':'New York City','limit':50,'offset':i}
    business_data.append(businessCallGET(b_params).json())

business_data
# Out:
# [{'businesses': [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#     'alias': 'prince-street-pizza-new-york-2',
#     'name': 'Prince Street Pizza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 3395,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.7229087705545,
#      'longitude': -73.9944863319397},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '27 Prince St',
#      'address2': None,
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10012',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['27 Prince St', 'New York, NY 10012']},
#     'phone': '+12129664100',
#     'display_phone': '(212) 966-4100',
#     'distance': 1941.9638172538225},
#    {'id': 'WIhm0W9197f_rRtDziq5qQ',
#     'alias': 'lombardis-pizza-new-york-4',
#     'name': "Lombardi's Pizza",
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 6076,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7215934960083,
#      'longitude': -73.9955956044561},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '32 Spring St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10012',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['32 Spring St', 'New York, NY 10012']},
#     'phone': '+12129417994',
#     'display_phone': '(212) 941-7994',
#     'distance': 1798.9959778083735},
#    {'id': 'ysqgdbSrezXgVwER2kQWKA',
#     'alias': 'julianas-pizza-brooklyn-5',
#     'name': "Juliana's Pizza",
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 2157,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.7026153030093,
#      'longitude': -73.9934159993549},
#     'transactions': [],
#     'price': '$$',
#     'location': {'address1': '19 Old Fulton St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11201',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#     'phone': '+17185966700',
#     'display_phone': '(718) 596-6700',
#     'distance': 323.20506308227306},
#    {'id': 'v1DHGRNCH9247WLYoaoA9A',
#     'alias': 'l-industrie-pizzeria-brooklyn',
#     'name': "L'industrie Pizzeria",
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SRL_RztRRUijgQwt67daGw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 504,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '254 S 2nd St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11211',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#     'phone': '+17185990002',
#     'display_phone': '(718) 599-0002',
#     'distance': 3145.016041338447},
#    {'id': 'EMKsuz1fQIGqmWPp3ZEDmA',
#     'alias': 'vitos-slices-and-ices-new-york-2',
#     'name': "Vito's Slices and Ices",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fJIjHHeoPqWa9ee-eBdqXA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/vitos-slices-and-ices-new-york-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 73,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'shavedice', 'title': 'Shaved Ice'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 5.0,
#     'coordinates': {'latitude': 40.7545, 'longitude': -73.99528},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '464 9th Ave',
#      'address2': None,
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10018',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['464 9th Ave', 'New York, NY 10018']},
#     'phone': '+12122731186',
#     'display_phone': '(212) 273-1186',
#     'distance': 5451.624567147119},
#    {'id': 'nUpA3sY5b6dynC7aj0eV6A',
#     'alias': 'rizzos-fine-pizza-new-york-4',
#     'name': "Rizzo's Fine Pizza",
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dnLj-NVZx4TUp608hDVBvw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/rizzos-fine-pizza-new-york-4?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 722,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'wine_bars', 'title': 'Wine Bars'},
#      {'alias': 'beerbar', 'title': 'Beer Bar'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.720852, 'longitude': -73.984456},
#     'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#     'price': '$$',
#     'location': {'address1': '17 Clinton St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10002',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['17 Clinton St', 'New York, NY 10002']},
#     'phone': '+16464541262',
#     'display_phone': '(646) 454-1262',
#     'distance': 1903.2788345091096},
#    {'id': 'uc5qQMzs96rzjK27epDCug',
#     'alias': 'joes-pizza-new-york-4',
#     'name': "Joe's Pizza",
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG9HFmEGaTSBMcUBhA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 2505,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.730655, 'longitude': -74.002189},
#     'transactions': [],
#     'price': '$',
#     'location': {'address1': '7 Carmine St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10014',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['7 Carmine St', 'New York, NY 10014']},
#     'phone': '+12123661182',
#     'display_phone': '(212) 366-1182',
#     'distance': 2881.2882146124957},
#    {'id': 'WG639VkTjmK5dzydd1BBJA',
#     'alias': 'rubirosa-new-york-2',
#     'name': 'Rubirosa',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 2169,
#     'categories': [{'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.72275, 'longitude': -73.99622},
#     'transactions': [],
#     'price': '$$',
#     'location': {'address1': '235 Mulberry St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10012',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#     'phone': '+12129650500',
#     'display_phone': '(212) 965-0500',
#     'distance': 1931.2683716470422},
#    {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#     'alias': 'bleecker-street-pizza-new-york',
#     'name': 'Bleecker Street Pizza',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP43S_a6s-zXD38NUQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 2323,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7320627016512,
#      'longitude': -74.0036552270137},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '69 7th Ave S',
#      'address2': None,
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10014',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#     'phone': '+12129244466',
#     'display_phone': '(212) 924-4466',
#     'distance': 3072.9540450669765},
#    {'id': 'FhXjAc6nKLf414KxYujUHw',
#     'alias': 'robertas-brooklyn-2',
#     'name': "Roberta's",
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8fY9fA5TtCF0ebdTNph9mQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 2794,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.705043534338, 'longitude': -73.93357123374},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '261 Moore St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11206',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#     'phone': '+17184171118',
#     'display_phone': '(718) 417-1118',
#     'distance': 5118.690592147886},
#    {'id': 'aTXpZudGAKCihlF_zaqBIg',
#     'alias': 'f-and-f-pizzeria-brooklyn',
#     'name': 'F & F Pizzeria',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EV3RDMoMlt8jumgdG9-vwQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/f-and-f-pizzeria-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 71,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 40.67732, 'longitude': -73.99817},
#     'transactions': [],
#     'location': {'address1': '459 Court St',
#      'address2': '',
#      'address3': None,
#      'city': 'Brooklyn',
#      'zip_code': '11231',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['459 Court St', 'Brooklyn, NY 11231']},
#     'phone': '',
#     'display_phone': '',
#     'distance': 3143.452033762742},
#    {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#     'alias': 'johns-of-bleecker-street-new-york-2',
#     'name': "John's of Bleecker Street",
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/azvVfskp-0QuI4G51R8_VA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 1970,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '278 Bleecker St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10014',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#     'phone': '+12122431680',
#     'display_phone': '(212) 243-1680',
#     'distance': 3010.899021476809},
#    {'id': '2ggi1luerd3Mf_C82JvCYg',
#     'alias': 'grimaldis-pizzeria-brooklyn-4',
#     'name': "Grimaldi's Pizzeria",
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNKqW31PTvtSw6-Lbc1mtA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 4590,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 40.702583, 'longitude': -73.9932413},
#     'transactions': [],
#     'price': '$$',
#     'location': {'address1': '1 Front St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11201',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#     'phone': '+17188584300',
#     'display_phone': '(718) 858-4300',
#     'distance': 330.34746206527655},
#    {'id': 'tluWdKIinSkg8pOY1qVVeQ',
#     'alias': 'square-pizza-new-york-3',
#     'name': 'Square Pizza',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gzB80_aNZiSlB5-TDbOOhQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/square-pizza-new-york-3?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 2,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 5.0,
#     'coordinates': {'latitude': 40.72008, 'longitude': -73.98468},
#     'transactions': ['pickup', 'delivery'],
#     'location': {'address1': '37-39 Clintons St',
#      'address2': None,
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10002',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['37-39 Clintons St', 'New York, NY 10002']},
#     'phone': '+12128372566',
#     'display_phone': '(212) 837-2566',
#     'distance': 1809.2070678630603},
#    {'id': 'C8j0q4Ma_S5hBGuAI-aaww',
#     'alias': 'di-fara-pizza-brooklyn',
#     'name': 'Di Fara Pizza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4dfe9qpe20P-vi3qFjWd4Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 3402,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.625093, 'longitude': -73.961531},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '1424 Ave J',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11230',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['1424 Ave J', 'Brooklyn, NY 11230']},
#     'phone': '+17182581367',
#     'display_phone': '(718) 258-1367',
#     'distance': 9352.269072867253},
#    {'id': 'Q9F2ocrmYuGt1yn3M7MOBw',
#     'alias': 'lucali-brooklyn-3',
#     'name': 'Lucali',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Yl_eZ_DW_iaumnU-pfSoaw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 1494,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.6818, 'longitude': -74.00024},
#     'transactions': [],
#     'price': '$$',
#     'location': {'address1': '575 Henry St',
#      'address2': None,
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11231',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['575 Henry St', 'Brooklyn, NY 11231']},
#     'phone': '+17188584086',
#     'display_phone': '(718) 858-4086',
#     'distance': 2677.3041083372636},
#    {'id': 'hGksyTiHBBdrhbiVjXzWVw',
#     'alias': 'scarrs-pizza-new-york',
#     'name': "Scarr's Pizza",
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k3iXzXNevY7-CuIbE0-FaQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 363,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.71534, 'longitude': -73.9914},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '22 Orchard St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10002',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['22 Orchard St', 'New York, NY 10002']},
#     'phone': '+12123343481',
#     'display_phone': '(212) 334-3481',
#     'distance': 1125.7843300426755},
#    {'id': 'BgGz5IdV53bGb4o7opR5zg',
#     'alias': 'arturos-new-york',
#     'name': "Arturo's",
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Eh-8a3MUYlpatlpHs3mHJg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/arturos-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 674,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7273563342024,
#      'longitude': -74.0004944801331},
#     'transactions': ['restaurant_reservation'],
#     'price': '$$',
#     'location': {'address1': '106 W Houston St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10012',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['106 W Houston St', 'New York, NY 10012']},
#     'phone': '+12126773820',
#     'display_phone': '(212) 677-3820',
#     'distance': 2491.867165709998},
#    {'id': '4h4Tuuc56YPO6lWfZ1bdSQ',
#     'alias': 'joes-pizza-new-york-152',
#     'name': "Joe's Pizza",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iiFPnKfxI2_UjJHbCd2iCQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/joes-pizza-new-york-152?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 171,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7101297729083,
#      'longitude': -74.0077206864953},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '124 Fulton St',
#      'address2': '',
#      'address3': None,
#      'city': 'New York',
#      'zip_code': '10038',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['124 Fulton St', 'New York, NY 10038']},
#     'phone': '+12122670860',
#     'display_phone': '(212) 267-0860',
#     'distance': 1245.9428626945232},
#    {'id': 'yH6t1JWcwkdWG4CS5KPvow',
#     'alias': 'adriennes-pizzabar-new-york',
#     'name': "Adrienne's Pizzabar",
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOG8wpqkeYQxDslq7ospLw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/adriennes-pizzabar-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 1642,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'beerbar', 'title': 'Beer Bar'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7043362, 'longitude': -74.0101733},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '54 Stone St',
#      'address2': None,
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10004',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['54 Stone St', 'New York, NY 10004']},
#     'phone': '+12122483838',
#     'display_phone': '(212) 248-3838',
#     'distance': 1344.2671600758972},
#    {'id': 'pGr5QuQU7Ur5GHLvXbT8bw',
#     'alias': 'paulie-gees-brooklyn',
#     'name': "Paulie Gee's",
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1j39J4NABK_RBtO-l90QNg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 1223,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'vegan', 'title': 'Vegan'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.729546, 'longitude': -73.958568},
#     'transactions': [],
#     'price': '$$',
#     'location': {'address1': '60 Greenpoint Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11222',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#     'phone': '+13479873747',
#     'display_phone': '(347) 987-3747',
#     'distance': 4027.308250680752},
#    {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#     'alias': 'joes-pizza-new-york-7',
#     'name': "Joe's Pizza",
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9E2Um0ddicKyoWS-RGIXyg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 863,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.73331, 'longitude': -73.98763},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '150 E 14th St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10003',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['150 E 14th St', 'New York, NY 10003']},
#     'phone': '+12123889474',
#     'display_phone': '(212) 388-9474',
#     'distance': 3133.9130768847594},
#    {'id': 'eVk4F9ixl89zyUHJ1G2Aiw',
#     'alias': 'luzzos-la-pizza-napoletana-new-york-10',
#     'name': 'Luzzos La Pizza Napoletana',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/siQq0MnFSCXmAd8rg28EwQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/luzzos-la-pizza-napoletana-new-york-10?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 1035,
#     'categories': [{'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.730616, 'longitude': -73.9834846},
#     'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#     'price': '$$',
#     'location': {'address1': '211 1st Ave',
#      'address2': None,
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10003',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['211 1st Ave', 'New York, NY 10003']},
#     'phone': '+12124737447',
#     'display_phone': '(212) 473-7447',
#     'distance': 2943.403489083045},
#    {'id': 'vyoA8dxwScuMV_AsTcjQcg',
#     'alias': 'l-and-b-spumoni-gardens-brooklyn',
#     'name': 'L & B Spumoni Gardens',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BrTci9PjIwi7V1vkbgkdqg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/l-and-b-spumoni-gardens-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 3698,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.594715, 'longitude': -73.981316},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '2725 86th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11223',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['2725 86th St', 'Brooklyn, NY 11223']},
#     'phone': '+17184491230',
#     'display_phone': '(718) 449-1230',
#     'distance': 12361.163422806636},
#    {'id': 'xrgzB0pvsxeGEIboE6I2gg',
#     'alias': 'patsys-pizzeria-brooklyn-2',
#     'name': "Patsy's Pizzeria",
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1n5xL5ojLR-_zseirQKaMw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/patsys-pizzeria-brooklyn-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 512,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.6818695, 'longitude': -73.976181},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '450 Dean St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11217',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#     'phone': '+17186222268',
#     'display_phone': '(718) 622-2268',
#     'distance': 3034.9893998767334},
#    {'id': 'ookYacn-U1pcyQA81sKmJg',
#     'alias': 'bella-roma-pizza-new-york',
#     'name': 'Bella Roma Pizza',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gz7pbFNuz6pMZxNxTBa6hA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/bella-roma-pizza-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 12,
#     'categories': [{'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.7738458, 'longitude': -73.9574025},
#     'transactions': ['pickup', 'delivery'],
#     'location': {'address1': '1379 Third Ave',
#      'address2': '',
#      'address3': None,
#      'city': 'New York',
#      'zip_code': '10075',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['1379 Third Ave', 'New York, NY 10075']},
#     'phone': '+12128795005',
#     'display_phone': '(212) 879-5005',
#     'distance': 8213.8724071603},
#    {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#     'alias': 'joes-pizza-new-york-148',
#     'name': "Joe's Pizza",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5P5i2QZhxCen55PNdU_TTg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 1018,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7545841255557,
#      'longitude': -73.9870039190341},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '1435 Broadway',
#      'address2': '',
#      'address3': None,
#      'city': 'New York',
#      'zip_code': '10018',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['1435 Broadway', 'New York, NY 10018']},
#     'phone': '+16465594878',
#     'display_phone': '(646) 559-4878',
#     'distance': 5498.444221355099},
#    {'id': 'DJSLGbSqCJ1W8ma3LFlMuw',
#     'alias': 'patzeria-perfect-pizza-new-york',
#     'name': 'Patzeria Perfect Pizza',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w62on7rHWF6ZNTVy6M6RuQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/patzeria-perfect-pizza-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 1597,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'diners', 'title': 'Diners'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7594653910395,
#      'longitude': -73.9867857052142},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '231 W 46th St',
#      'address2': None,
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10036',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['231 W 46th St', 'New York, NY 10036']},
#     'phone': '+12125757646',
#     'display_phone': '(212) 575-7646',
#     'distance': 6040.018561992213},
#    {'id': 'xxgcU_oFIox_pAmroo9WwA',
#     'alias': 'front-street-pizza-brooklyn',
#     'name': 'Front Street Pizza',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ybrfmg0lGdBoJRM7X1_s3A/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/front-street-pizza-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 348,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.70244, 'longitude': -73.98943},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '80 Front St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11201',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['80 Front St', 'Brooklyn, NY 11201']},
#     'phone': '+17188753700',
#     'display_phone': '(718) 875-3700',
#     'distance': 550.4392264831844},
#    {'id': 'xsQTIeq-WLkp4ParkTQpMQ',
#     'alias': 'pizzarte-new-york',
#     'name': 'PizzArte',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KG9Kbt1xrxsl_xm4qQrngQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/pizzarte-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 1078,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7629335072372,
#      'longitude': -73.9776668697596},
#     'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '69 W 55th St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10019',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['69 W 55th St', 'New York, NY 10019']},
#     'phone': '+12122473936',
#     'display_phone': '(212) 247-3936',
#     'distance': 6544.13958857817},
#    {'id': 'ZTsN8TdMXl8SW_AKd_ablw',
#     'alias': 'forno-rosso-brooklyn',
#     'name': 'Forno Rosso',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9aKNymymd9out1HSpkLuiA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/forno-rosso-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 677,
#     'categories': [{'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.694467, 'longitude': -73.98293},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '327 Gold St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11201',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['327 Gold St', 'Brooklyn, NY 11201']},
#     'phone': '+17184513800',
#     'display_phone': '(718) 451-3800',
#     'distance': 1546.804489135146},
#    {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#     'alias': 'joes-pizza-brooklyn-8',
#     'name': "Joe's Pizza",
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7RQebflR3JvTcMWRbVC86g/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 306,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.71691, 'longitude': -73.958987},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '216 Bedford Ave',
#      'address2': '',
#      'address3': None,
#      'city': 'Brooklyn',
#      'zip_code': '11249',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#     'phone': '+17183882216',
#     'display_phone': '(718) 388-2216',
#     'distance': 3239.2966565668607},
#    {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#     'alias': 'ny-pizza-suprema-new-york',
#     'name': 'NY Pizza Suprema',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 1977,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7502059936523,
#      'longitude': -73.9953231811523},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '413 8th Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10001',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['413 8th Ave', 'New York, NY 10001']},
#     'phone': '+12125948939',
#     'display_phone': '(212) 594-8939',
#     'distance': 4977.847939164096},
#    {'id': '2ZALEmIVm_t4tYLGXxd2dw',
#     'alias': 'lions-and-tigers-and-squares-detroit-pizza-new-york-2',
#     'name': 'Lions & Tigers & Squares Detroit Pizza',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qDn08nlYzOk3WDLxSwGzwQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/lions-and-tigers-and-squares-detroit-pizza-new-york-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 50,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.72981, 'longitude': -73.98658},
#     'transactions': ['pickup', 'delivery'],
#     'location': {'address1': '160 2nd Ave',
#      'address2': '',
#      'address3': None,
#      'city': 'New York',
#      'zip_code': '10003',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['160 2nd Ave', 'New York, NY 10003']},
#     'phone': '',
#     'display_phone': '',
#     'distance': 2784.2019328185065},
#    {'id': 'atbANdSznV29GI066I2Ijw',
#     'alias': 'champion-pizza-new-york-6',
#     'name': 'Champion Pizza',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SV5N-uxEa1tHUXYLAi43xA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/champion-pizza-new-york-6?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 313,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.7215270996094,
#      'longitude': -73.9970855712891},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '17 Cleveland Pl',
#      'address2': None,
#      'address3': None,
#      'city': 'New York',
#      'zip_code': '10012',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['17 Cleveland Pl', 'New York, NY 10012']},
#     'phone': '+12122263777',
#     'display_phone': '(212) 226-3777',
#     'distance': 1801.4764439408825},
#    {'id': 'oRdM7n-AfBPBGAlH4Q0Sag',
#     'alias': 'my-pie-pizzeria-romana-new-york-2',
#     'name': 'My Pie Pizzeria Romana',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vo36uaolTTa5aREAcddJnw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/my-pie-pizzeria-romana-new-york-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 741,
#     'categories': [{'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.7608512, 'longitude': -73.9694809},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '690 Lexington Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10022',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#     'phone': '+12123171850',
#     'display_phone': '(212) 317-1850',
#     'distance': 6505.9564779774955},
#    {'id': 'zmIrZgWhRdyRMrnEs9D3KA',
#     'alias': 'la-margarita-pizzeria-new-york',
#     'name': 'La Margarita Pizzeria',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7NH6z9iOZETlq8AKFwkcyQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-margarita-pizzeria-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 285,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.7215392420787,
#      'longitude': -73.9876275438289},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '168 Ludlow St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10002',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['168 Ludlow St', 'New York, NY 10002']},
#     'phone': '+19172614983',
#     'display_phone': '(917) 261-4983',
#     'distance': 1875.7222956933838},
#    {'id': 'k3vbv0tbV83IrfaH2Z5t5Q',
#     'alias': 'maneros-pizza-new-york',
#     'name': "Manero's Pizza",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4C4o_uuLbnIxEe0GftP-lg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/maneros-pizza-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 35,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.717593, 'longitude': -73.998396},
#     'transactions': ['pickup', 'delivery'],
#     'location': {'address1': '113 Mulberry St',
#      'address2': '',
#      'address3': None,
#      'city': 'New York',
#      'zip_code': '10013',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['113 Mulberry St', 'New York, NY 10013']},
#     'phone': '',
#     'display_phone': '',
#     'distance': 1398.553837392163},
#    {'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#     'alias': 'artichoke-basilles-pizza-new-york-2',
#     'name': "Artichoke Basille's Pizza",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/53JHO_-CRJ_e43JJIuN_Og/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 3938,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7321124557704,
#      'longitude': -73.9839056828882},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '321 E 14th St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10003',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['321 E 14th St', 'New York, NY 10003']},
#     'phone': '+12122282004',
#     'display_phone': '(212) 228-2004',
#     'distance': 3091.822113723405},
#    {'id': 'SpyQHasbnU5YkOR6PI4sNQ',
#     'alias': 'margherita-nyc-new-york',
#     'name': 'Margherita NYC',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LliRmU4qe3LzVnKRy8b6og/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/margherita-nyc-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 302,
#     'categories': [{'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.7189865112305,
#      'longitude': -73.9969329833984},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '197 Grand St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10013',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['197 Grand St', 'New York, NY 10013']},
#     'phone': '+12122268391',
#     'display_phone': '(212) 226-8391',
#     'distance': 1531.530627996726},
#    {'id': 'hFmz7HH2og9hn7xNNv20yw',
#     'alias': 'il-porto-ristorante-brooklyn',
#     'name': 'Il Porto Ristorante',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ka4_bkUB_I5JAZyRjAnbLQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/il-porto-ristorante-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 314,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.6974427, 'longitude': -73.9675197},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '37 Washington Ave',
#      'address2': None,
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11205',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['37 Washington Ave', 'Brooklyn, NY 11205']},
#     'phone': '+17186240954',
#     'display_phone': '(718) 624-0954',
#     'distance': 2433.857388341044},
#    {'id': 'm3PS0tIaa0ChcP8Y5S-DrQ',
#     'alias': 'mamas-too-new-york',
#     'name': "MAMA'S TOO!",
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NTpvPQSoxumdAuc6szUSyQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/mamas-too-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 310,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 40.80084, 'longitude': -73.96766},
#     'transactions': [],
#     'price': '$$',
#     'location': {'address1': '2750 Broadway',
#      'address2': '',
#      'address3': None,
#      'city': 'New York',
#      'zip_code': '10025',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['2750 Broadway', 'New York, NY 10025']},
#     'phone': '+12125107256',
#     'display_phone': '(212) 510-7256',
#     'distance': 10840.163726815497},
#    {'id': 'cdkPnLb1Sr2gGnoYsrR5BQ',
#     'alias': 'nolita-pizza-new-york',
#     'name': 'Nolita Pizza',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m372fb2o_EAmLuXLs1W5Hg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/nolita-pizza-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 28,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.72834, 'longitude': -73.98764},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '128 2nd Ave',
#      'address2': None,
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10003',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['128 2nd Ave', 'New York, NY 10003']},
#     'phone': '+16467564141',
#     'display_phone': '(646) 756-4141',
#     'distance': 2605.432634033249},
#    {'id': '-CCfu19Uuy_kD2t4ZwsQfA',
#     'alias': 'village-square-pizza-new-york-3',
#     'name': 'Village Square Pizza',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rc1se5XkYcc6ABo8g7u4Zw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/village-square-pizza-new-york-3?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 116,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.72748, 'longitude': -73.98268},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '147 Ave A',
#      'address2': None,
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10009',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['147 Ave A', 'New York, NY 10009']},
#     'phone': '+19176757709',
#     'display_phone': '(917) 675-7709',
#     'distance': 2640.263835248777},
#    {'id': 'i_rg-OLXQbpRUN7O3MeCeA',
#     'alias': 'piz-zetta-brooklyn-2',
#     'name': 'Piz-zetta',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9L4viDwAGx3obgYLnXMA6g/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/piz-zetta-brooklyn-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 280,
#     'categories': [{'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.6912834070746,
#      'longitude': -73.9906029201042},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '90 Livingston St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11201',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['90 Livingston St', 'Brooklyn, NY 11201']},
#     'phone': '+17184227878',
#     'display_phone': '(718) 422-7878',
#     'distance': 1605.1176697811002},
#    {'id': 'MphfKkYFEe0BDQ6hZ0A5fA',
#     'alias': 'gelso-and-grand-new-york',
#     'name': 'Gelso & Grand',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HuHFQ0vaGnMsBu_5QcprXA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/gelso-and-grand-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 882,
#     'categories': [{'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'pastashops', 'title': 'Pasta Shops'},
#      {'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.7194089547259,
#      'longitude': -73.9973777877722},
#     'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#     'price': '$$',
#     'location': {'address1': '186 Grand St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10013',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['186 Grand St', 'New York, NY 10013']},
#     'phone': '+12122261600',
#     'display_phone': '(212) 226-1600',
#     'distance': 1574.3490321455226},
#    {'id': 'orvnuNWLuoE3-iEx4Aj8eA',
#     'alias': 'bakers-pizza-new-york',
#     'name': "Baker's Pizza",
# ...
#     'price': '$',
#     'location': {'address1': '7101 Fort Hamilton Pkwy',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11228',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['7101 Fort Hamilton Pkwy', 'Brooklyn, NY 11228']},
#     'phone': '+17187459326',
#     'display_phone': '(718) 745-9326',
#     'distance': 8813.068364664776},
#    {'id': 'oVOJRE1fAecZMN1Uo0Fv3g',
#     'alias': 'san-remo-pizzeria-and-restaurant-ridgewood',
#     'name': 'San Remo Pizzeria & Restaurant',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AVB13iwt09x1ENplO_ipAw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/san-remo-pizzeria-and-restaurant-ridgewood?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 45,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 40.700332, 'longitude': -73.906135},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '5601 Myrtle Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Ridgewood',
#      'zip_code': '11385',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['5601 Myrtle Ave', 'Ridgewood, NY 11385']},
#     'phone': '+17184971903',
#     'display_phone': '(718) 497-1903',
#     'distance': 7457.284607173214},
#    {'id': '1Ylu26XW3F6gSJWdFw6-8g',
#     'alias': 'great-burrito-new-york',
#     'name': 'Great Burrito',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1YHRh26gV0oit0zhASGplw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/great-burrito-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 244,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'mexican', 'title': 'Mexican'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.7428322, 'longitude': -73.9930115},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '100 W 23rd St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10011',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['100 W 23rd St', 'New York, NY 10011']},
#     'phone': '+12122430022',
#     'display_phone': '(212) 243-0022',
#     'distance': 4161.184956632597},
#    {'id': 'H3vJZbpCABkmc7HnyQOGag',
#     'alias': 'whitepoint-pizza-restaurant-college-point-2',
#     'name': 'Whitepoint Pizza Restaurant',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v2c4G8_HQnvYEKvuZT2AhA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/whitepoint-pizza-restaurant-college-point-2?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 113,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 40.7863815, 'longitude': -73.8354221},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '132-13 14th Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'College Point',
#      'zip_code': '11356',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['132-13 14th Ave', 'College Point, NY 11356']},
#     'phone': '+17187465555',
#     'display_phone': '(718) 746-5555',
#     'distance': 16143.429127183339},
#    {'id': 'uxLzUC9QxbxyCCau32cf0A',
#     'alias': 'joes-pizza-bronx-3',
#     'name': "Joe's Pizza",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LITP9mwaTkDfOj3EpCmdLg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/joes-pizza-bronx-3?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 32,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.844169, 'longitude': -73.830093},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '3009A Middletown Rd',
#      'address2': '',
#      'address3': '',
#      'city': 'Bronx',
#      'zip_code': '10461',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['3009A Middletown Rd', 'Bronx, NY 10461']},
#     'phone': '+17189313145',
#     'display_phone': '(718) 931-3145',
#     'distance': 20716.106251743917},
#    {'id': 'lSelLuQYWfKMrYO_Dka_Qw',
#     'alias': 'fiamma-41-bayside',
#     'name': 'Fiamma 41',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B8RJ9qAYAsPyNqp3RzphZQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/fiamma-41-bayside?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 387,
#     'categories': [{'alias': 'bars', 'title': 'Bars'},
#      {'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.763566, 'longitude': -73.769942},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '214-26 41st Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Bayside',
#      'zip_code': '11361',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['214-26 41st Ave', 'Bayside, NY 11361']},
#     'phone': '+17182255700',
#     'display_phone': '(718) 225-5700',
#     'distance': 19977.382817700425},
#    {'id': 'a0ib8o6hBkVE2vI-pt0mUg',
#     'alias': 'termini-pizzeria-union-city',
#     'name': 'Termini Pizzeria',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_9C0OsKy5bkiygfkc2FKnQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/termini-pizzeria-union-city?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 39,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 40.77705, 'longitude': -74.0255899},
#     'transactions': [],
#     'price': '$$',
#     'location': {'address1': '4107 Bergenline Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Union City',
#      'zip_code': '07087',
#      'country': 'US',
#      'state': 'NJ',
#      'display_address': ['4107 Bergenline Ave', 'Union City, NJ 07087']},
#     'phone': '+12018667336',
#     'display_phone': '(201) 866-7336',
#     'distance': 8400.894412266276},
#    {'id': 'QR6w6bdxpRzYvF9URmyHHg',
#     'alias': 'claudio-pizzeria-new-york-5',
#     'name': 'Claudio Pizzeria',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OqsSzCWrDYPqyzKDqlQgXQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/claudio-pizzeria-new-york-5?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 85,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'italian', 'title': 'Italian'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 40.7604, 'longitude': -73.99469},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '598 10th Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10036',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['598 10th Ave', 'New York, NY 10036']},
#     'phone': '+12125863145',
#     'display_phone': '(212) 586-3145',
#     'distance': 6104.444678884859},
#    {'id': '56CzRdvWvVxju9ia_MXgug',
#     'alias': 'la-mia-pizza-new-york',
#     'name': 'La Mia Pizza',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nnrH2GmxzKbznHc9aeBHdA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-mia-pizza-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 204,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 40.774822, 'longitude': -73.953295},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '1488 1st Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10075',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['1488 1st Ave', 'New York, NY 10075']},
#     'phone': '+12124721200',
#     'display_phone': '(212) 472-1200',
#     'distance': 8452.357622909736},
#    {'id': 'Zmp8NaqKOapPEUw5Ufv4rQ',
#     'alias': 'caruso-pizzeria-and-restaurant-brooklyn',
#     'name': 'Caruso Pizzeria &  Restaurant',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DuJS6fMTUrKUr1wXz2NpDQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/caruso-pizzeria-and-restaurant-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 65,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 40.686637, 'longitude': -73.990783},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '150 Smith St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11201',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['150 Smith St', 'Brooklyn, NY 11201']},
#     'phone': '+17187972300',
#     'display_phone': '(718) 797-2300',
#     'distance': 2111.9633507119324},
#    {'id': 'ESo8Hm27TFi6U3kBzHKeIg',
#     'alias': 'pizza-den-brooklyn',
#     'name': 'Pizza Den',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1rN9_iTKx1iKvP2xzplTcQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/pizza-den-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 100,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 40.607266, 'longitude': -74.002255},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '8521 18th Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11214',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['8521 18th Ave', 'Brooklyn, NY 11214']},
#     'phone': '+17188372350',
#     'display_phone': '(718) 837-2350',
#     'distance': 10933.444201247823},
#    {'id': 'QPFxwkDYbc55C-nWQm36FA',
#     'alias': '99-cent-fresh-pizza-new-york-12',
#     'name': '99 Cent Fresh Pizza',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v3SVsedgxr-a5JUeg0CK0A/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-12?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 99,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.754799, 'longitude': -73.987272},
#     'transactions': [],
#     'price': '$',
#     'location': {'address1': '143 W 40th St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10018',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['143 W 40th St', 'New York, NY 10018']},
#     'phone': '+12123665550',
#     'display_phone': '(212) 366-5550',
#     'distance': 5519.721273020938},
#    {'id': '-CDfgsM40aA7siEEpR66hw',
#     'alias': 'cafe-daniellos-new-york',
#     'name': "Cafe Daniello's",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WFeUGI3XZHgCFDcDulXxiA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/cafe-daniellos-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 103,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 40.758768, 'longitude': -73.965332},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$$',
#     'location': {'address1': '1072 2nd Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10022',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['1072 2nd Ave', 'New York, NY 10022']},
#     'phone': '+12127525710',
#     'display_phone': '(212) 752-5710',
#     'distance': 6411.785244521594},
#    {'id': 'JmDZuDrYrtEKKVr0PypSVA',
#     'alias': 'lennys-pizza-brooklyn',
#     'name': "Lenny's Pizza",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8WEPkAa0AqkT64ZXWVlj5A/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/lennys-pizza-brooklyn?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 149,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 40.60502, 'longitude': -73.99862},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '1969 86th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Brooklyn',
#      'zip_code': '11214',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['1969 86th St', 'Brooklyn, NY 11214']},
#     'phone': '+17189461292',
#     'display_phone': '(718) 946-1292',
#     'distance': 11167.226545330674},
#    {'id': 'h37t9rA06Sr4EetJjKrfzw',
#     'alias': 'don-angie-new-york',
#     'name': 'Don Angie',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j5cm0Ku1lMJ8ikvVlmO1sw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/don-angie-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 294,
#     'categories': [{'alias': 'italian', 'title': 'Italian'},
#      {'alias': 'newamerican', 'title': 'American (New)'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 40.73778, 'longitude': -74.00197},
#     'transactions': [],
#     'price': '$$$',
#     'location': {'address1': '103 Greenwich Ave',
#      'address2': '',
#      'address3': None,
#      'city': 'New York',
#      'zip_code': '10014',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['103 Greenwich Ave', 'New York, NY 10014']},
#     'phone': '+12128898884',
#     'display_phone': '(212) 889-8884',
#     'distance': 3657.6947913177873},
#    {'id': 'SQba0_SKF7wypTBAUyrrgA',
#     'alias': 'pizza-and-pita-new-york',
#     'name': 'Pizza & Pita',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k66VgLYgq91fOFr3CfzNdA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/pizza-and-pita-new-york?adjust_creative=kT71ybq7zvzehA6rhQl7MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kT71ybq7zvzehA6rhQl7MA',
#     'review_count': 59,
#     'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#      {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 40.74382, 'longitude': -73.97401},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '344 E 34th St',
#      'address2': '',
#      'address3': '',
#      'city': 'New York',
#      'zip_code': '10016',
#      'country': 'US',
#      'state': 'NY',
#      'display_address': ['344 E 34th St', 'New York, NY 10016']},
#     'phone': '+12126796161',
#     'display_phone': '(212) 679-6161',
#     'distance': 4593.928639000372}],
#   'total': 11100,
#   'region': {'center': {'longitude': -73.99429321289062,
#     'latitude': 40.70544486444615}}}]

# %%
# #from page1001 to page 1901+50
# offset=list(range(1001,1950,50))
# business_data1=[]
# for i in offset:
#     b_params={'term':'pizza','location':'New York City','limit':50,'offset':i}
#     business_data1.append(businessCallGET(b_params).json())

# business_data1

# %%
b_data=business_data.copy()
# Out:
# 27 Prince St
# 32 Spring St
# 19 Old Fulton St
# 254 S 2nd St
# 464 9th Ave
# 17 Clinton St
# 7 Carmine St
# 235 Mulberry St
# 69 7th Ave S
# 261 Moore St
# 459 Court St
# 278 Bleecker St
# 1 Front St
# 37-39 Clintons St
# 1424 Ave J
# 575 Henry St
# 22 Orchard St
# 106 W Houston St
# 124 Fulton St
# 54 Stone St
# 60 Greenpoint Ave
# 150 E 14th St
# 211 1st Ave
# 2725 86th St
# 450 Dean St
# 1379 Third Ave
# 1435 Broadway
# 231 W 46th St
# 80 Front St
# 69 W 55th St
# 327 Gold St
# 216 Bedford Ave
# 413 8th Ave
# 160 2nd Ave
# 17 Cleveland Pl
# 690 Lexington Ave
# 168 Ludlow St
# 113 Mulberry St
# 321 E 14th St
# 197 Grand St
# 37 Washington Ave
# 2750 Broadway
# 128 2nd Ave
# 147 Ave A
# 90 Livingston St
# 186 Grand St
# 201 Avenue A
# 277 Broome St
# 175 Kent Ave
# 128 Central Ave
# 1524 Neptune Ave
# 567 Vanderbilt Ave
# 110 Franklin St
# 19 1st Ave
# 168 1st Ave
# 146 W Houston St
# 84 Rivington St
# 364 Grand St
# 77 Fulton St
# 63 Clinton St
# 443 Knickerbocker Ave
# 83 1st Ave
# 1723 Broadway
# 214 Hicks St
# 48 E 12th St
# 298 Atlantic Ave
# 370 W 51st St
# 80 Henry St
# 290 8th Ave
# 740 Broadway
# 3 Greenwich Ave
# 232 Vanderbilt Ave
# 50 2nd Ave
# 2287 1st Ave
# 145 1st Ave
# Pier 6 Brooklyn Bridge Park
# 148 Bedford Ave
# 326 Roebling St
# 226 E 14th St
# 139 Broadway
# 346 Himrod St
# 33 Havemeyer St
# 230 Park Ave
# 63 Wall St
# 275 Church St
# 326 Dekalb Ave
# 136-55 Roosevelt Ave
# 268 W 23rd St
# 29 E 29th St
# 513 W 27th St
# 351 Broome St
# 849 Manhattan Ave
# 338 Hamilton Ave
# 279 71st St
# 381 Broadway
# 27 Avenue B
# 374 Metropolitan Ave
# 145 Atlantic Ave
# 170 Rivington St
# 691 6th Ave
# 50 Macdougal St
# 15671 Crossbay Blvd
# 97 Washington St
# 435 Halsey St
# 127 Stanton St
# 87 Atlantic Ave
# 2848 Broadway
# 431 DeKalb Ave
# 275 Grove St
# 191 Graham Ave
# 117 W 57th St
# 679 9th Ave
# 98 Ave B
# 245 E 14th St
# 287 Hudson St
# 781 Franklin Ave
# 325 Church St
# 423 Troutman St
# 462-466 2nd Ave
# 200 5th Ave
# 358 Graham Ave
# 345 E 12th St
# 379 Park Ave S
# 303 West 127th St
# 421 Amsterdam Ave
# 349 E 12th St
# 127 Avenue C
# 81-34 Baxter Ave
# 3 Hanover Sq
# 179 Bedford Ave
# 620 Manhattan Ave
# 26 Vesey St
# 3412 31st Ave
# 123 W 3rd St
# 2547 Broadway
# 20 Union Square W
# 800 6th Ave
# 345 Adams St
# 1559 2nd Ave
# 547 9th Ave
# 141 Lawrence St
# 4407 Queens Blvd
# 115 Delancey St
# 35 Downing St
# 4 Water St
# 165 Bleecker St
# 102 Berry St
# 626 Hudson St
# 176 2nd Ave
# 83 Henry St
# 784 Washington Ave
# 754 10th Ave
# 93 Macdougal St
# 1 W 58th St
# 178 Mulberry St
# 905 Church Ave
# 50 Fulton St
# 411 Washington St
# 54 -18 31st Ave
# 260 W 44th St
# 76 Ainslie St
# 669 Union St
# 303 Amsterdam Ave
# 101 Ludlow St
# 568 Amsterdam Ave
# 686 5th Ave
# 469 5th Ave
# 334 Bowery
# 26 Broadway
# 524 Port Richmond Ave
# 90-92 Gansevoort St
# 225 Park Row
# 989 1st Ave
# 310 2nd Ave
# 365 3rd Ave
# 445 Albee square W
# 28 West St
# 311 W 48th St
# 28 Carmine St
# 705 Flatbush Ave
# 214 Front St
# 1739 2nd Ave
# 473 3rd Ave
# 214 Court St
# 271 Bleecker St
# 57 Pearl St
# 32 St Marks Pl
# 140 W 13th St
# 135 West 116th St
# 40 Wall St
# 309 W 50th St
# 755 Flatbush Ave
# 14 Newkirk Plz
# 114 10th Ave
# 123 Essex St
# 198 Union Ave
# 178 Lexington Ave
# 488 9th Ave
# 59 5th Ave
# 801 2nd Ave
# 204 Grand St
# 15 W 28th St
# 524 4th Ave
# 629 2nd Ave
# 68 Bergen St
# 244 E 13th St
# 1079 Broadway
# 307 W 17th St
# 482 Myrtle Ave
# 177 Spring St
# 179 3rd Ave
# 65 8th Ave
# 42 Ave A
# 510 Columbus Ave
# 458 Myrtle Ave
# 330 S 3rd St
# 1946 37th St
# 5526 69th St
# 111 MacDougal St
# 6922 5th Ave
# 267 Smith St
# 457 Graham Ave
# 65 2nd Ave
# 81-28 Lefferts Blvd
# 155 Atlantic Ave
# 227 Lenox Ave
# 652 Myrtle Ave
# 450 Hudson St
# 49 Beach St
# 353 Myrtle Ave
# 1631 2nd Ave
# 1596 Amsterdam Ave
# 1814 2nd Ave
# 81 Catherine St
# 297 Broadway
# 570 Putnam Ave
# 318 Grand St
# 656 6th Ave
# 544 Lorimer St
# 98 7th Ave
# 438 3rd Ave
# 77 Pearl St
# 223 Madison St
# 598 8th Ave
# 455 Main St
# 132 E 56th St
# 3013 Steinway St
# 819 9th Ave
# 376 Classon Ave
# 265 Union Ave
# 42-12 28th St
# 383 Canal St
# 1 Perry St
# 70 Pine St
# 201 Clinton St
# 1376 Lexington Ave 91st St
# 83 Maiden Ln
# 29-11 23rd Ave
# 41-16 Queens Blvd
# 39-37 30th St
# 399 Grand St
# 690 Fulton St
# 336 Knickerbocker Ave
# 27 Saint James Pl
# 134-24 Crossbay Blvd
# 525 Grand St
# 77-09 37th Ave
# 3 Clinton St
# 3027 Stratton St
# 36-08 30th Ave
# 1300 Crosby Ave
# 1668 Sheepshead Bay Rd
# 140 7th Ave
# 21 Greenpoint Ave
# 123 E 41st St
# 173 Orchard St
# 493 2nd Ave
# 175 Nassau Ave
# 842 Franklin Ave
# 16 E 41st St
# 55 W 45th St
# 709 Knickerbocker Ave
# 1017 Manhattan Ave
# 1552 Fulton St
# 39 W 46th St
# 11 Park Pl
# 2476 Broadway
# 326 Van Brunt St
# 121 Dyckman St
# 225 Murray St
# 51 Spring St
# 1563 Decatur St
# 114 Court St
# 275 Grand Ave
# 451 3rd Ave
# 804 W 187th St
# 48-11 Vernon Blvd
# 2146 2nd Ave
# 758 Nostrand Ave
# 9110 3rd Ave
# 4087 Broadway
# 625 9th Ave
# 312 Utica Ave
# 2 W 14th St
# 132 Union St
# 1697 Broadway
# 61 W 74th St
# 353 W 14th St
# 1142 Broadway
# 340 Franklin Ave
# 8504 5th Ave
# 190 Cypress Ave
# 226 4th Ave
# 49 W 24th St
# 157 Bleecker St
# 118 Greenwich Ave
# 581 Myrtle Ave
# 7109 Grand Ave
# 38-28 27th St
# 100 Wall St
# 103 N 3rd St
# 359 7th Ave
# 68 Kenmare St
# 186 Columbus Ave
# 685 Franklin Ave
# 145 E 49th St
# 109 Franklin St
# 241 Bushwick Ave
# 318 Flatbush Ave
# 1233 1st Ave
# 62 E 34th St
# 3143 Broadway
# 8610 5th Ave
# 31 W 46th St
# 512 Grand St
# 9514 Ave L
# 386 Canal St
# 788 Manhattan Ave
# 108-26 Ascan Ave
# 371 Grand St
# 1 Penn Plz
# 9824 4th Ave
# 7305 3rd Ave
# 347 Court St
# 3658 Broadway
# 291 3rd Ave
# 1055 1st Ave
# 174 N 4th St
# 331 Lenox Ave
# 274 W 40th St
# 607 2nd Ave
# 6265 Fresh Pond Rd
# 7112 13th Ave
# 503 W 28th St
# 42-60 Crescent St
# 1670 3rd Ave
# 65 Carmine St
# 26-21 Jackson Ave
# 101 Liberty St
# 1717 Broadway
# 137 7th Ave
# 599 Flatbush Ave
# 263 1st St
# 93 Howard Ave
# 71-47 Kissena Blvd
# 1159 3rd Ave
# 190 Bleecker St
# 166 West 72nd St
# 7022 3rd Ave
# 305 Court St
# 4033 E Tremont Ave
# 590 E 191st St
# 284 5th Ave
# 181 E Broadway
# 144 9th Ave
# 58 2nd Ave
# 1431 1st Ave
# 4001 Queens Blvd
# 105 Mulberry St
# 415 2nd Ave
# 44 9th Ave
# 174 Avenue B
# 29 East 33rd St
# 570 Lexington Ave
# 1413 Rockaway Pkwy
# 371 1st Ave
# 4973 Broadway
# 175 Orchard St
# 144 Orchard St
# 41-02 Broadway
# 2255 31st St
# 323 7th Ave
# 245 3rd Ave
# 1636 Broadway
# 432 Union Ave
# 1374 1st Ave
# 70 Vanderbilt Ave
# 350 3rd Ave
# 334 8th Ave
# 6322 18th Ave
# 6322 18th Ave
# 600 11th Ave
# 141 Fulton St
# 167 Orchard St
# 28-17 Astoria Blvd
# 71 2nd Ave
# 172 5th Ave
# 41-02 Astoria Blvd
# 485 Lorimer St
# 451 Carroll St
# 226 Varick St
# 85 5th Ave
# 318 W 23rd St
# 311 Smith St
# 204 9th Ave
# 86 Nassau Ave
# 35 Broadway
# 218 48th St
# 876 6th Ave
# 70-05 Myrtle Ave
# 221 W 38th St
# 221 Ave A
# 136 W 42nd St
# 3435 Fulton St
# 181 Ave C
# 2 Gold St
# 177 E Houston St
# 8 Cortlandt St
# 1505 Lexington Ave
# 1426 Lexington Ave
# 755 6th Ave
# 74-02 Metropolitan Ave
# 101 W 68th St
# 683 5th Ave
# 737 Fulton St
# 8635 Broadway
# 231 1st Ave
# 505 Grand St
# 133 Clinton St
# 3511 35th Ave
# 40 Wyckoff Ave
# 1762 2nd Ave
# 6514 18th Ave
# 4455 Broadway
# 85 7th Ave
# 33-02 35th Ave
# 753 Washington St
# 6305 Fort Hamilton Pkwy
# 151 E 43rd St
# 384 Broome St
# 7116 Bay Pkwy
# 181 7th Ave
# 261 5th Ave
# 89 Canal St
# 163-04 Jamaica Ave
# 91 Ave A
# 11-03 36th Ave
# 111 N 12th St
# 1494 1st Ave
# 444 7th Ave
# 11 Waverly Pl
# 231 Mott St
# 59 Nassau St
# 83 Saint Marks Pl
# 33 Hudson St
# 647 4th Ave
# 924 Columbus Ave
# 164 William St
# 1600 Amsterdam Ave
# 457 Baldwin Ave
# 557 8th Ave
# 765 Dekalb Ave
# 1 E 33rd St
# 1590 Lexington Ave
# 337 E 10th St
# 546 3rd Ave
# 437 Palisade Ave
# 62-69 Dry Harbor Rd
# 9601 69th Ave
# 80-14 Roosevelt Ave
# 5819 Woodside Ave
# 63 Wall St
# 40-15 Bell Blvd
# 5910 Myrtle Ave
# 147 E Houston St
# 2671 Broadway
# 207 Ave U
# 31 Great Jones St
# 224 Dekalb Ave
# 1018 Amsterdam Ave
# 511 E 5th St
# 315 Broadway
# 81-21 37th Ave
# 1142 3rd Ave
# 60 Hancock St
# 1731 2nd Ave
# 1477 York Ave
# 6918 3rd Ave
# 304 W 14th St
# 624 Vanderbilt Ave
# 1469 2nd Ave
# 760 8th Ave
# 1484 2nd Ave
# 204-23 Hillside Ave
# 1572 3rd Ave
# 388 Ave Of The Americas
# 401 E 57th St
# 105-03 Metropolitan Ave
# 34-23 Steinway St
# 200 5th Ave
# 153 Ave C
# 881 10th Ave
# 14 E 37th St
# 2147 Mill Ave
# 117 Ferris St
# 922 2nd Ave
# 749 Lydig Ave
# 301 West 57th St
# 1324 Ave J
# 59-40 Myrtle Ave
# 8608 117th St
# 1367 Broadway
# 63 4th Ave
# 257 Park Ave S
# 2578 Broadway
# 1675 Nostrand Ave
# 772 Castle Hill Ave
# 14720 Northern Blvd
# 210 Hudson St
# 355 Graham Ave
# 44-06 60th St
# 1279 Castle Hill Ave
# 69 New St
# 958 3rd Ave
# 704 Burke Ave
# 31-1 21st St
# 45-19 28th Ave
# 821 W 181st
# 2166 Frederick Douglass Blvd
# 1957 Victory Blvd
# 12038 Queens Blvd
# 278 New Dorp Ln
# 169 W 33rd St
# 12 Russell Ave
# 22 Warren St
# 585 Myrtle Ave
# 154 Church St
# 1051 Morris Park Ave
# 488 8th Ave
# 1610 York Ave
# 1610 York Ave
# 5102 Fort Hamilton Pkwy
# 919 Fulton St
# 1686 Pitkin Ave
# 688 6th Ave
# 238 Court St
# 129 MacDougal St
# 80 N 7th St
# 148 N 7th St
# 52-27 69th St
# 1307 Myrtle Ave
# 700 3rd Ave
# 2134 Flatbush Ave
# 187 Mulberry St
# 1000 8th Ave
# 36 Ralph Ave
# 418 Ditmas Ave
# 1279 1st Ave
# 548 Flatbush Ave
# 3161 Broadway
# 76 Bay St
# 1603 2nd Ave
# 512 7th Ave
# 2047 Broadway
# 257 7th Ave
# 928 Broadway
# 2351 Ralph Ave
# 187 Bedford Ave
# 5806 5th Ave
# 1617 2nd Ave
# 115 E 14th St
# One Fifth Avenue At 8th St
# 1408 Cortelyou Rd
# 176 Prince St
# 531 Malcolm X Blvd
# 1024 Amsterdam Ave
# 460 W 34th St
# 15 W 21st St
# 1082 Morris Park Ave
# 333B Avenue Of The America
# 145 E 49th St
# 72 5th Ave
# 834 Broadway
# 135 Newark Ave
# 51 Willoughby St
# 360 7th Ave
# 119 Wyckoff Ave
# 7414 5th Ave
# 224 W 35th St
# 349 5th Ave
# 852 8th Ave
# 936 2nd Ave
# 2823 Middletown Rd
# 965 Lexington Ave
# 4206 Park Ave
# 374 Central Ave
# 238 36th St
# 348 Bowery
# 1375 Avenue Of The Americas
# 985 1st Ave
# 8906 Northern Blvd
# 483 Amsterdam Ave
# 67 6th Ave
# 504 E 138th St
# 1527 149th St
# 3625 Kingsbridge Ave
# 1850 3rd Ave
# 2255 2nd Ave
# 14 Rector St
# 7704 5th Ave
# 139 Ct St
# 6061 Fresh Pond Rd
# 380 Central Ave
# 2026 Bedford Ave
# 3620 Ditmars Blvd
# 33-00 Northern Blvd
# 579 Grand Concourse
# 386 Canal St
# 235 Smith St
# 214 10th Ave
# 10320 Liberty Ave
# 260 Warren St
# 446 Dean St
# 43-02 Bell Blvd
# 351 W 125th St
# 231 W 39th St
# 294 Broadway
# 513 Columbus Ave
# 723 Washington Ave
# 2067 2nd Ave
# 101 7th Ave S
# 445 Court St
# 129 Mulberry St
# 411 Amsterdam Ave
# 686 6th Ave
# 558 Driggs Ave
# 720 Flatbush Ave
# 26C Macombs Pl
# 123 MacDougal St
# 850 Nostrand Ave
# 1443 York Ave
# 36-08 Ditmars Blvd
# 3337 Fulton St
# 90 Bedford St
# 1110 Lexington Ave
# 112-15 Linden Blvd
# 775 Madison St
# 6907 Grand Ave
# 2107 Broadway
# 840 8th Ave
# 30 Rockefeller Plz
# 6127 Bergenline Ave
# 1140 Bay St
# 502 Amsterdam Ave
# 32 Court St
# 188 E 104th St
# 6935 Grand Ave
# 2716 Gerritsen Ave
# 1266 150th St
# 9 Thames St
# 8816 3rd Ave
# 3705 Broadway
# 395 Flatbush Ave
# 101-139 W 33rd St
# 5408 Ave N
# 92-15 Jamaica Ave
# 110 W 145th St
# 89-89 Union Tpke
# 159 Greenpoint Ave
# 11 Varick St
# 5660 Mosholu Ave
# 4910 5th Ave
# 2823 Ave U
# 252 W 51st St
# 5506 Myrtle Ave
# 883 First Ave
# 686 Morris Park Ave
# 3035 Fulton St
# 150 Dyckman St
# 1649 Park Ave
# 382 8th Ave
# 621 9th Ave
# 345 E 83rd St
# 26 1st Ave
# 303 S End Ave
# 21 Flushing Ave
# 600 E 187th St
# 96 Hudson St
# 55 Water St
# 2426 Pitkin Ave
# 68 Lorraine St
# 533 Newark Ave
# 47-23 Vernon Blvd
# 1022 Madison Ave
# 119 E 96th St
# 131 Christopher St
# 1 E 43rd St
# 21 Bedford Park Blvd E
# 256 E 125th St
# 994 Columbus Ave
# 158 Montague St
# 218 Flatbush Ave
# 930 3rd Ave
# 528 Gateway Dr
# 78 Rivington St
# 232 W 231st St
# 535 Hudson St
# 200 5th Ave
# 127 E Broadway
# 25-19 40th Ave
# 790 11th Ave
# 1204 Flatbush Ave
# 24-17 Ditmars Blvd
# 1758 Victory Blvd
# 1304 2nd Ave
# 89-01 101st Ave
# 2178 86th St
# 1260 Amsterdam Ave
# 107 W 37th St
# 6 E 42nd St
# 18808 Union Tpke
# 302 W 37th St
# 3524 Johnson Ave
# 3915 9th Ave
# 3738 Riverdale Ave
# 3211 Quentin Rd
# 323 Greenwich St
# 2 E 33rd St
# 403 Amsterdam Ave
# 156 Delancey St
# 180 Varick St
# 542 9th Ave
# 3021 Church Ave
# 363 Smith St
# 195 10th Ave
# 122 University Pl
# 79-16 21st Ave
# 3007 Fort Hamilton Pkwy
# 679 Seneca Ave
# 554 Vanderbilt Ave
# 120 E 34th St
# 7708 3rd Ave
# 7701 Broadway
# 31-01 Newtown Ave
# 730 10th Ave
# 41 Exchange Pl
# 2392 21st St
# 791 Flushing Ave
# 7901 17th Anenue
# 4704 3rd Ave
# 150 E 2nd St
# 2169 Broadway
# 1146 Nostrand Ave
# 18504 Horace Harding Expy
# 921 E 174th St
# 330 Halsey St
# 6625 Fresh Pond Rd
# 16819 Union Tpke
# 34-23 Steinway St
# 1162 1st Ave
# 527 6th Ave
# 112 9th Ave
# 21 West End Ave
# 211 8th Ave
# 212 Market St
# 183 Newark Ave
# 3050 14th St
# 146 5th Ave
# 50-22 39th Ave
# 171 W 23rd St
# 225 W 57th St
# 148 5th Ave
# 3409 Broadway
# 941 Amsterdam Ave
# 45-59 47th St
# 19 W Fordham Rd
# 1366 Pennsylvania Ave
#
# 66 Charlton St
# 426A 7th Ave
# 675 Onderdonk Ave
# 5 Hyatt St
# 961 Columbus Ave
# 244 W 56th St
# 107-12 70th Rd
# 503 Frank E Rodgers Blvd N
# 6855 Forest Ave
# 1667 1st Ave
# 1038 1st Ave
# 6610 Ave U
# 5654 Riverdale Ave
# 87 Sussex St
# 5123 108th St
# 39-63 61st St
# 44 N 6th St
# 1049 Brighton Beach Ave
# 358 E 2nd St
# 254 Irving Ave
# 775 Woodward Ave
# 8507 Jamaica Ave
# 3411 Broadway
# 844 2nd Ave
# 215 Columbia St
# 100 Dekalb Ave
# 4525 Broadway
# 105 W 28th St
# 639 S Broad St
# 135-17 Lefferts Blvd
# 1529 86th St
# 8102 Rockaway Blvd
# 57 W 57th St
# 278 Central Ave
# 6424 14th Ave
# 7 E 27th St
# 1248 Lexington Ave
# 9502 Church Ave
# 539 Park Ave
# 8130 Broadway
# 1295 3rd Ave
# 404 Hunts Point Ave
# 9010 Jamaica Ave
# 424 Greenwood Ave
# 30-01 Broadway
# 1427 3rd Ave
# 22-56 31st St
# 603 Washington St
# 2270 Nostrand Ave
# 3932 Broadway
# 526 3rd Ave
# 1000 Willow Ave
# 28-17 36th Ave
# 6510 11th Ave
# 1701 1st Ave
# 43-18 Ditmars Blvd
# 445 Albee Square W
# None
# 2109 Broadway
# 745 Manhattan Ave
# 907 Livonia Ave
# 2 St Marks Pl
# 528 Columbus Ave
# 2 Pennsylvania Plz
# 1599 Westchester Ave
# 41-07 Greenpoint Ave
# 584 Broadway
# 1627 Mermaid Ave
# 606 2nd St
# 136 Alexander Ave
# 41-10 49th St
# 536 W 30th St
# 1800 Kings Hwy
# 253 Nassau Ave
# 1747 Amsterdam Ave
# 2358 80th St
# 6460 Dry Harbor Rd
# 55 Water St
# 388 3rd Ave
# 136 Mulberry St
# 370 W 58th St
# 1102 Bedford Ave
# 660 Amsterdam Ave
# 416 3rd Ave
# 2007 127th St
# 265 Canal St
# 1522 Amsterdam Ave
# 173 1st Ave
# 900 7th Ave
# 180 7th Ave S
# 9615 Liberty Ave
# 1412 Saint Johns Pl
# 832 6th Ave
# 894 Dekalb Ave
# 9910 63rd Rd
# 43-22 43rd Ave
# 133 Newark Ave
# 6568 Myrtle Ave
# 696 10th Ave
# 2036 Flatbush Ave
# 485 7th Ave
# 1240 Hancock St
# 7-26 149th St
# 936 8th Ave
# 206 E 60th St
# 70 McLean Ave
# 149-21 Rockaway Blvd
# 2004 Williamsbridge Rd
# 6229 Kennedy Blvd
# 839 Prospect Ave
# 3307 Church Ave
# 2157 Knapp St
# 44-08 Greenpoint Ave
# 1235 Prospect Ave
# 9403 5th Ave
# 1398 Madison Ave
# 259 Prospect Park W
# 500 Jefferson St
# 107-23 Metropolitan Ave
# 982 2nd Ave
# 63-27 108th St
# 270 Kingston Ave
# 242 E 50th St
# 6823 4th Ave
# 350 W 46th St
# 2703 Church Ave
# 473 Lexington Ave
# 346 Grove St
# 6824 Colonial Rd
# 6827 Myrtle Ave
# 860 Post Ave
# 739 9th Ave
# 1-50 50th Ave
# 19509 69th Ave
# 1323 Ave U
# 9853 63rd Rd
# 19213 47th Ave
# 1215 Surf Ave
# 1806 Church Ave
# 28-15 24th Ave
# 2640 Broadway
# 529 Henry St
# 60 Broadway
# 594 5th Ave
# 489 Third Ave
# 3204 30th Ave
# 8921 Old River Rd
# 3617 E Tremont Ave
# 171-01 Northern Blvd
# 8125 5th Ave
# 150 E 116th St
# 3065 14th St
# 113 Jane St
# 2370 Belmont Ave
# 20 Beaver St
# 29 7th Ave S
# 299 Malcolm X Blvd
# 300 Clarendon St
# 18 Wyckoff Ave
# 3145 Fulton St
# 622 Washington St
# 4412 Fort Hamilton Pkwy
# 810 W 181st St
# 90 Maiden Ln
# 8949A Bay Pkwy
# 153 Bergen Blvd
# 8424 13th Ave
# 260 Mamaroneck Ave
# 46 Beard St
# 200 Spring St
# 1319 Washington St
# 89 E 42nd St
# 110 9th Ave
# 34-24 30th Ave
# 261 Ave X
# 1731 Crosby Ave
# 326 Spring St
# 220 Varick St
# 51 W 51st St
# 483 5th Ave
# 509 Albany Ave
# 89 Washington St
# 18-32 College Point Blvd
# 1626A Bedford Ave
# 1760 1st Ave
# 292 E 204th St
# 15 Giffords Ln
# 819 Broadway
# 2791 Broadway
# 34 E 4th St
# 272 W 135th St
# 328 Palisade Ave
# 7623 13th Ave
# 674 Broadway
# 1076 Jackson Ave
# 1215 Amsterdam Ave
# 7101 Fort Hamilton Pkwy
# 5601 Myrtle Ave
# 100 W 23rd St
# 132-13 14th Ave
# 3009A Middletown Rd
# 214-26 41st Ave
# 4107 Bergenline Ave
# 598 10th Ave
# 1488 1st Ave
# 150 Smith St
# 8521 18th Ave
# 143 W 40th St
# 1072 2nd Ave
# 1969 86th St
# 103 Greenwich Ave
# 344 E 34th St

# %%
#'id', 'name', 'price','phone','review_count', 'rating', 'location', , 
business_id=[]
name=[]
review_count=[]
rating=[]
stree=[]
state=[]
zip_code=[]
country=[]


for i in b_data:
    for j in i['businesses']:
        business_id.append(j['id'])
        name.append(j['name'])
        review_count.append(j['review_count'])
        rating.append(j['rating'])
        stree.append(j['location']['address1'])
        state.append(j['location']['state'])
        zip_code.append(j['location']['zip_code'])
        country.append(j['location']['country'])

# %%
#for price 
price=[]
for i in b_data:
    for j in i['businesses']:
        if 'price' in j.keys():
            len(j['price'])
            price.append(len(j['price']))       
        else:
            None 
            price.append(None)

len(price)
# Out:
# 1000

# %%
#for phone

phone=[]
for i in b_data:
    for j in i['businesses']:
        if 'phone' in j.keys():
            j['phone']
            phone.append(j['phone'])       
        else:
            None 
            phone.append(None)

len(phone)
# Out:
# 1000

# %%
 pd.DataFrame(location).head()
#len(pd.DataFrame(location))
# Out:
#            address1 address2 address3      city zip_code country state  \
# 0      27 Prince St     None           New York    10012      US    NY
# 1      32 Spring St                    New York    10012      US    NY
# 2  19 Old Fulton St                    Brooklyn    11201      US    NY
# 3      254 S 2nd St                    Brooklyn    11211      US    NY
# 4       464 9th Ave     None           New York    10018      US    NY
#
#                           display_address
# 0      [27 Prince St, New York, NY 10012]
# 1      [32 Spring St, New York, NY 10012]
# 2  [19 Old Fulton St, Brooklyn, NY 11201]
# 3      [254 S 2nd St, Brooklyn, NY 11211]
# 4       [464 9th Ave, New York, NY 10018]

# %%
# #For location 
# street=pd.DataFrame(location)['address1']
# city=pd.DataFrame(location)['city']
# zip_code=pd.DataFrame(location)['zip_code']
# state=pd.DataFrame(location)['state']
# country=pd.DataFrame(location)['country']

# print(len(id),len(name),len(review_count),len(rating),len(price),len(phone),
#       len(street),len(city),len(zip_code),len(state),len(country))

# %%
# #Create an empty dataframe for future use 
# b_data1=pd.DataFrame() #'review_count', 'rating',  'price', 'location', 'phone',
# b_data1['business_id']=id
# b_data1['name']=name
# b_data1['review_count']=review_count
# b_data1['rating']=rating
# b_data1['price']=price
# b_data1['phone']=phone
# b_data1['stree']=street
# b_data1['city']=city
# b_data1['zip_code']=zip_code
# b_data1['state']=state
# b_data1['country']=country

# %%
#b_data1.head(10)
len(set(b_data1['business_id']))
# Out:
# 998

# %%
for i in business_id:
        if business_id.count(i)>1:
            print(i)
# Out:
# P90fQ5WHs381XvgEibs9OQ
# P90fQ5WHs381XvgEibs9OQ
# Cjg5steonbecyrjYIuHv9A
# Cjg5steonbecyrjYIuHv9A

# %%
business_id.index('P90fQ5WHs381XvgEibs9OQ')
# Out:
# 399

# %%
business_id.index('Cjg5steonbecyrjYIuHv9A')
# Out:
# 549

# %%
# Create a table for the reviews
def reviewCallGET(id_num):
    reviewEndpoint_base = 'https://api.yelp.com/v3/businesses/'
    reviewEndpoint_end = '/reviews'
    return {id_num:requests.get(reviewEndpoint_base + id_num + reviewEndpoint_end,headers=headers1).json()}

# %%
# for i in review_data ['id', 'text', 'rating', 'time_created', 'user']
review=[]
for i in b_data1['business_id']:
    review.append(reviewCallGET(i))
                                
review
# Out:
# [{'zj8Lq1T8KIC5zwFief15jg': {'reviews': [{'id': 'H4eanmM_xB5MESW0vYWXlQ',
#      'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=H4eanmM_xB5MESW0vYWXlQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Every time you go by here, there is a line out the door. Dont be fooled as there is nowhere inside to stand inside!  That is the catch right?  Long lines...',
#      'rating': 5,
#      'time_created': '2020-01-24 07:57:41',
#      'user': {'id': 'vbXmCVj1RZ4civT7nrcKyw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=vbXmCVj1RZ4civT7nrcKyw',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/RWKo_mp182lqS89xrnLbNg/o.jpg',
#       'name': 'Erik H.'}},
#     {'id': 'm9qzCxMLgv-SUsk_3-HeKQ',
#      'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=m9qzCxMLgv-SUsk_3-HeKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Probably the best pizza I've ever had. Line is always out the door and down the block. \n\nOne thing you love but may also find disgusting is the pepperoni...",
#      'rating': 5,
#      'time_created': '2020-01-22 19:11:56',
#      'user': {'id': 'ZOPzFRCl8jIX4LJKkXnYqw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=ZOPzFRCl8jIX4LJKkXnYqw',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/cCdElJb8Yg-pa3W4HEtNeQ/o.jpg',
#       'name': 'Marquis F.'}},
#     {'id': 'hVX_Umb4lpGVRn8Kvt7bVQ',
#      'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=hVX_Umb4lpGVRn8Kvt7bVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Went back to this place after dreaming about the pizza for a year. I wanted 6 slices for three of us so I asked for a small peppornni. The guy tells me they...',
#      'rating': 3,
#      'time_created': '2020-01-22 08:26:38',
#      'user': {'id': 'WQMVlWOyn1b-gQ0SEXgksQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=WQMVlWOyn1b-gQ0SEXgksQ',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/-KGg0eRTLreOaiX-XhAUxQ/o.jpg',
#       'name': 'Frank R.'}}],
#    'total': 3395,
#    'possible_languages': ['fr', 'en', 'ja', 'da']}},
#  {'WIhm0W9197f_rRtDziq5qQ': {'reviews': [{'id': 'rL0eMviisPenimX2WBWEmQ',
#      'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=rL0eMviisPenimX2WBWEmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'This place is exactly what it is.\n\nOffers Delicious perfect pizza - like the double pepperoni.  Fresh pasta like the parppadelle with house made pesto. \n\nNo...',
#      'rating': 4,
#      'time_created': '2020-01-19 09:26:46',
#      'user': {'id': 'STAlhmm3saZDehwqzEg5wg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=STAlhmm3saZDehwqzEg5wg',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/SgXvWYQUjwJKaco7YyajHg/o.jpg',
#       'name': 'Jenny K. L.'}},
#     {'id': 'QTWApHdTxBrGNDXlkIk0YA',
#      'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=QTWApHdTxBrGNDXlkIk0YA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Went with my family last weekend after deciding not to justify a 2 and a half hour long wait at rubirosa. Have passed this place a million times but haven't...",
#      'rating': 1,
#      'time_created': '2020-01-18 17:35:20',
#      'user': {'id': 'aDCP6CHiv6vp_2opUEPUHQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=aDCP6CHiv6vp_2opUEPUHQ',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/4bS7N3f97jR7T1zS6i219Q/o.jpg',
#       'name': 'Hannah M.'}},
#     {'id': '7RkNMzgm2o81vuDc5d1H2Q',
#      'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=7RkNMzgm2o81vuDc5d1H2Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "I personally liked the taste/texture of this pizza better than Joe's (although my friend disagrees), but I didn't really like Joe's that much in the first...",
#      'rating': 3,
#      'time_created': '2020-01-14 23:58:53',
#      'user': {'id': 'qxqJRxvUAYZAjk0P7Rkgig',
#       'profile_url': 'https://www.yelp.com/user_details?userid=qxqJRxvUAYZAjk0P7Rkgig',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/5rlOjv4RPHc4UtEjmnPGjQ/o.jpg',
#       'name': 'Iris F.'}}],
#    'total': 6077,
#    'possible_languages': ['fr',
#     'en',
#     'pt',
#     'de',
#     'it',
#     'sv',
#     'es',
#     'fi',
#     'pl']}},
#  {'ysqgdbSrezXgVwER2kQWKA': {'reviews': [{'id': 'GItqAWpYoGQZu-lMuqJmFg',
#      'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=GItqAWpYoGQZu-lMuqJmFg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'We heard about the story of Juliana so we had to come try it! After walking the whole bridge we were ready to eat! \nWhen we got there, there was a line......',
#      'rating': 5,
#      'time_created': '2020-01-14 14:33:08',
#      'user': {'id': '34QEXPleSt0qtkUCo94vNQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=34QEXPleSt0qtkUCo94vNQ',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/FQVcSS0R6XzgvSm9SxBcHQ/o.jpg',
#       'name': 'Shelly C.'}},
#     {'id': '07fSxrTbYkFzSeJC9IpmWw',
#      'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=07fSxrTbYkFzSeJC9IpmWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "I've tried and ranked a lot of pizza places in New York City and this is by far the easiest 5/5 star and my favorite pizza in all of NYC. The pizza is so...",
#      'rating': 5,
#      'time_created': '2020-01-09 19:24:39',
#      'user': {'id': '-cg5YzbDrrhQASiSN0RjTQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=-cg5YzbDrrhQASiSN0RjTQ',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/mAjllbrupQuNiUBCCbl17w/o.jpg',
#       'name': 'Sabrina P.'}},
#     {'id': 'k33aZ5T1S2f8aXA_OHvong',
#      'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=k33aZ5T1S2f8aXA_OHvong&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Came here on a Thursday afternoon with some friends after a buddy claimed this was one of the best pizza spots and a Brooklyn favourite. We got a large...',
#      'rating': 4,
#      'time_created': '2020-01-09 14:45:41',
#      'user': {'id': 'A8aizhKg9c9Pi1MK6gkH2A',
#       'profile_url': 'https://www.yelp.com/user_details?userid=A8aizhKg9c9Pi1MK6gkH2A',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/aJLNQd4wC4CQh3T8ImtA0w/o.jpg',
#       'name': 'Yousef K.'}}],
#    'total': 2157,
#    'possible_languages': ['fr', 'en', 'pt', 'nb', 'de', 'it', 'ja', 'es']}},
#  {'v1DHGRNCH9247WLYoaoA9A': {'reviews': [{'id': 'Sp5Md-Y2ACFtDRGau3hA9A',
#      'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=Sp5Md-Y2ACFtDRGau3hA9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'This pizza spot is low and is an absolute monster! \n\nPasses the plain slice test with flying colors. The crust is perfect carrier for their high quality...',
#      'rating': 5,
#      'time_created': '2020-01-17 15:10:45',
#      'user': {'id': 'G0rzekzEldaqkgrNZkkfAQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=G0rzekzEldaqkgrNZkkfAQ',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/3expYEmmG9_Adz8DuVIRFw/o.jpg',
#       'name': 'Oleg D.'}},
#     {'id': '_wKt4PvoxyG0EyVbeFNzvw',
#      'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=_wKt4PvoxyG0EyVbeFNzvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Just a takeout window with a couple of chairs really, but the quality of the food is there. Their style is a mix of Italy and New York, with square burrata...',
#      'rating': 5,
#      'time_created': '2019-11-22 09:35:59',
#      'user': {'id': 'iJ97UrvPlGNttp44qsJ-4A',
#       'profile_url': 'https://www.yelp.com/user_details?userid=iJ97UrvPlGNttp44qsJ-4A',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/HrOsQ8_gkFtJS50gMo4_WQ/o.jpg',
#       'name': 'John B.'}},
#     {'id': 'NE5WfQhqEeklUdxvVyoR8g',
#      'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=NE5WfQhqEeklUdxvVyoR8g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'This place is small, but it packs a punch!  \n\nI was able to try a few slices at this spot and I have to say the pizza had a great texture and flavor to it....',
#      'rating': 5,
#      'time_created': '2019-11-21 08:49:19',
#      'user': {'id': 'dAr6e-x6izK_Pi5OFAqiIg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=dAr6e-x6izK_Pi5OFAqiIg',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/h7LAExgdg3y9RJSRALpB0g/o.jpg',
#       'name': 'Nobel V.'}}],
#    'total': 506,
#    'possible_languages': ['de', 'zh', 'it', 'en']}},
#  {'EMKsuz1fQIGqmWPp3ZEDmA': {'reviews': [{'id': 'kRuHb6ngXLiHcAwMqTkk3w',
#      'url': 'https://www.yelp.com/biz/vitos-slices-and-ices-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=kRuHb6ngXLiHcAwMqTkk3w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Great pizza for a cheap price that is also open earlier than other places in the area so that you can have an early lunch.\nHonestly, delicious pizza and...',
#      'rating': 5,
#      'time_created': '2020-01-20 13:09:39',
#      'user': {'id': '1qXF97Qrv2BVVL4geyadDg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=1qXF97Qrv2BVVL4geyadDg',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/yu3diJf50hqeNwe4vHh9Cw/o.jpg',
#       'name': 'Alexandra B.'}},
#     {'id': 'dxsTfQ9grcDzDyVw5jTDwg',
#      'url': 'https://www.yelp.com/biz/vitos-slices-and-ices-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=dxsTfQ9grcDzDyVw5jTDwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'New update: Very Disappointed in this place, I tried to order delivery and they said it was only 15 minute walk/8 minute bike ride. And the people here...',
#      'rating': 1,
#      'time_created': '2020-01-19 16:40:58',
#      'user': {'id': 'u7tZR3RuFylIC--9_W5ELQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=u7tZR3RuFylIC--9_W5ELQ',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/815KpcTh40UYU32ESi-MTw/o.jpg',
#       'name': 'Kevin H.'}},
#     {'id': 'Gl04HYrX13I4QLu6cBQHWQ',
#      'url': 'https://www.yelp.com/biz/vitos-slices-and-ices-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=Gl04HYrX13I4QLu6cBQHWQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Small pizza shop with counter seating. We ordered a thick crust pepperoni slice, a cheese pizza slice, and Margherita pizza slice. The margherita was still...',
#      'rating': 5,
#      'time_created': '2020-01-13 17:22:55',
#      'user': {'id': 'bD1hmtqJ436dKfKsQ6UqWA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=bD1hmtqJ436dKfKsQ6UqWA',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/ofS2UzyFL8MJmqew1W1THA/o.jpg',
#       'name': 'Nina T.'}}],
#    'total': 73,
#    'possible_languages': ['en']}},
#  {'nUpA3sY5b6dynC7aj0eV6A': {'reviews': [{'id': 'CRWPzsAVgnqFMrTY1jfIgA',
#      'url': 'https://www.yelp.com/biz/rizzos-fine-pizza-new-york-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=CRWPzsAVgnqFMrTY1jfIgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Some of the best pizza in the city!\n\nThey have two storefronts, which are adjacent. One serves pizza by the slice, and it's perfect for a quick bite....",
#      'rating': 5,
#      'time_created': '2020-01-20 19:26:04',
#      'user': {'id': 'z7f8Vc52rjy3Y8P_Ah_zWQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=z7f8Vc52rjy3Y8P_Ah_zWQ',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/WnH8QLTrGP4JvuQYywfS-g/o.jpg',
#       'name': 'William Z.'}},
#     {'id': '0pNCR_jVwAFaXtRnR9IQ_w',
#      'url': 'https://www.yelp.com/biz/rizzos-fine-pizza-new-york-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=0pNCR_jVwAFaXtRnR9IQ_w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': '"Even bad pizza is good pizza"\n\nI think Plato said that, or maybe Casey Stengel, but it\'s a truth that we could always depend on, like how your metrocard is...',
#      'rating': 1,
#      'time_created': '2019-12-26 02:12:39',
#      'user': {'id': '4Y914Tnk4mVDboH1qgQmoA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=4Y914Tnk4mVDboH1qgQmoA',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/1sU9cCYyIshzkicsXWH3Yg/o.jpg',
#       'name': 'Anthony S.'}},
#     {'id': 'g37wpMjN9MqNMads11qNhQ',
#      'url': 'https://www.yelp.com/biz/rizzos-fine-pizza-new-york-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=g37wpMjN9MqNMads11qNhQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "As the pizza tour continues in 2019, Rizzo's offer a decent slice, or an entire pizza.\n\nThey offer different varieties for the traditional NY slice, to a...",
#      'rating': 5,
#      'time_created': '2019-12-07 05:42:47',
#      'user': {'id': 'dsq3wTz2Xe1xtkRrnZDl8Q',
#       'profile_url': 'https://www.yelp.com/user_details?userid=dsq3wTz2Xe1xtkRrnZDl8Q',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/sKPMeWcGgvvCxgM7lMKzSQ/o.jpg',
#       'name': 'Anthony D.'}}],
#    'total': 723,
#    'possible_languages': ['fr', 'en', 'it']}},
#  {'uc5qQMzs96rzjK27epDCug': {'reviews': [{'id': 'NLLoY6nCPJYcD_3O34TcTg',
#      'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=NLLoY6nCPJYcD_3O34TcTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Overall, NYC pizza is the best!  There are several places to get a tasty slice and each differ a bit.  Some even have a dusting of cornmeal on the bottom of...',
#      'rating': 5,
#      'time_created': '2020-01-12 11:52:50',
#      'user': {'id': 'C7e59OigLeUC3UQKldRLfw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=C7e59OigLeUC3UQKldRLfw',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/-75ywnRfJYIx7xPwPLK1ag/o.jpg',
#       'name': 'Tamara H.'}},
#     {'id': 'ycpVp9r-C2UY9FVBHeMsAw',
#      'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=ycpVp9r-C2UY9FVBHeMsAw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Very overhyped IMO :/ Maybe NY style just isn't my cup of tea, but I felt like biting into the mozzarella slice at Joe's just wasn't satisfying. I thought...",
#      'rating': 3,
#      'time_created': '2020-01-14 08:46:14',
#      'user': {'id': 'qxqJRxvUAYZAjk0P7Rkgig',
#       'profile_url': 'https://www.yelp.com/user_details?userid=qxqJRxvUAYZAjk0P7Rkgig',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/5rlOjv4RPHc4UtEjmnPGjQ/o.jpg',
#       'name': 'Iris F.'}},
#     {'id': 'YM0kiEbT1KTnGaB_rqjfsw',
#      'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=YM0kiEbT1KTnGaB_rqjfsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Of course we had to stop by this place! There was a line out the door on a Saturday night around 7:30pm but it moved pretty quickly. \n\nWe got a regular...',
#      'rating': 4,
#      'time_created': '2020-01-07 10:26:12',
#      'user': {'id': 'N-jLtUfESMkX9b7iqXtP_g',
#       'profile_url': 'https://www.yelp.com/user_details?userid=N-jLtUfESMkX9b7iqXtP_g',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/xGq8Kf1moHo_C6q8iRBBxw/o.jpg',
#       'name': 'Susan C.'}}],
#    'total': 2505,
#    'possible_languages': ['fr', 'en', 'es', 'pt', 'sv']}},
#  {'WG639VkTjmK5dzydd1BBJA': {'reviews': [{'id': 'w_9Lr1ElnO7XSMZs6aWrAg',
#      'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=w_9Lr1ElnO7XSMZs6aWrAg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Rubirosa is really well known for their thin crust pizza and every time I've been here--it's been always very delicious to have. Coming from Staten Island,...",
#      'rating': 5,
#      'time_created': '2020-01-17 18:38:38',
#      'user': {'id': '37HQzeYmTjyEknoErjZ1Ow',
#       'profile_url': 'https://www.yelp.com/user_details?userid=37HQzeYmTjyEknoErjZ1Ow',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/kGnIDdll4XaXSvPlDerQ3A/o.jpg',
#       'name': 'Harris D.'}},
#     {'id': 'HD_ejl83g-GZJ-M8-FR6hQ',
#      'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=HD_ejl83g-GZJ-M8-FR6hQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Rubirosa truly lived up to the hype! Their thin crust pizza is UNREAAAAAL! Def in my top 5 of NYC pizza. My boyfriend and I ordered 1/2 classic 1/2 vodka....',
#      'rating': 5,
#      'time_created': '2020-01-17 09:28:19',
#      'user': {'id': 'bNZPfnl5S45SYJQu3Zufcw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=bNZPfnl5S45SYJQu3Zufcw',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/62XVnhThb3aV1B2ktJVuxQ/o.jpg',
#       'name': 'Joanne S.'}},
#     {'id': 'qcXlnrYk_lraYsAau9UsZA',
#      'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=qcXlnrYk_lraYsAau9UsZA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Absolutely delicious and one of my favorite Italian spots in the city. It was my first time going to Rubirosa after being in New York since 2016, and I was...',
#      'rating': 5,
#      'time_created': '2020-01-15 13:44:45',
#      'user': {'id': '517ssFsXphTCU0MmOhG0yg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=517ssFsXphTCU0MmOhG0yg',
#       'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/MQJFhBZl7NyaI_wdSYtiBg/o.jpg',
#       'name': 'Eileen W.'}}],
#    'total': 2169,
#    'possible_languages': ['fr', 'de', 'tr', 'pt', 'en']}},
#  {'oJ_XSPZFpvIt6rvheSQl7A': {'reviews': [{'id': 'sZ4aBjRaCb4Un2t6vDwQaw',
#      'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=sZ4aBjRaCb4Un2t6vDwQaw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'So far, this is my favorite pizza place in NY. A quick subway ride from basically Madison Square Garden and a nice stroll through a pleasant neighborhood...',
#      'rating': 5,
#      'time_created': '2020-01-20 19:47:14',
#      'user': {'id': 'KVbDMKT6nRTFBmQPIN40BQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=KVbDMKT6nRTFBmQPIN40BQ',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/2al1M1OgfL6NaySuV1MKTA/o.jpg',
#       'name': 'Mariko F.'}},
#     {'id': '_lIYF5h5foDONyHyJOc2TA',
#      'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=_lIYF5h5foDONyHyJOc2TA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "This wasn't my favorite pizza in this part of town, but I loved my cheese pizza anyway. I love that there is a ton of room to sit (even if it's full, the...",
#      'rating': 5,
#      'time_created': '2019-12-30 18:28:37',
#      'user': {'id': 'Gcjr__StoE_lpZjDGc31Ew',
#       'profile_url': 'https://www.yelp.com/user_details?userid=Gcjr__StoE_lpZjDGc31Ew',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/n_lAD5JQL_ZCb1H-wHCtlg/o.jpg',
#       'name': 'Jeanette S.'}},
#     {'id': 'xi8dr5tvYvg0isQHXJDPqw',
#      'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=xi8dr5tvYvg0isQHXJDPqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Had to try to this place after my friends saw that I had Prince St. My wife and I were on the hunt for delicious NY pizza. \n\nThe moment we got there, we...',
#      'rating': 4,
#      'time_created': '2019-12-28 14:33:06',
#      'user': {'id': '92oz54w1L3MSFguvjx_-cQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=92oz54w1L3MSFguvjx_-cQ',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/EgH3GHx51ayXU5gYqc_9Qg/o.jpg',
#       'name': 'Robin C.'}}],
#    'total': 2324,
#    'possible_languages': ['fr', 'de', 'en', 'it']}},
#  {'FhXjAc6nKLf414KxYujUHw': {'reviews': [{'id': '_TXOV_a6fs0iWM3pSoYaDQ',
#      'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=_TXOV_a6fs0iWM3pSoYaDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "My boyfriend and I were eager to see what the hype was about. We came at 10:30am on a Saturday and were seated immediately. I'm allergic to dairy and don't...",
#      'rating': 5,
#      'time_created': '2019-12-28 13:07:18',
#      'user': {'id': 'w0joRXU7UxbJVb2Pkn3nWg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=w0joRXU7UxbJVb2Pkn3nWg',
#       'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/N2G_NrghT_yV-6pD0T6-3g/o.jpg',
#       'name': 'Sydney L.'}},
#     {'id': 'NxlQyXraJ7CC-T4AG9E_wA',
#      'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=NxlQyXraJ7CC-T4AG9E_wA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "The neighborhood of East Williamsburg was quiet, eerie, and gloomy. It wasn't until we stepped into Roberta's that I felt the warmth and comfy vibes come...",
#      'rating': 4,
#      'time_created': '2020-01-23 21:13:59',
#      'user': {'id': 'cK0b4QGCWmEghFkqboAHfA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=cK0b4QGCWmEghFkqboAHfA',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/3Boup3u-nrwJj_mvxZuQrA/o.jpg',
#       'name': 'Sandy D.'}},
#     {'id': 'txv14QlmLth-_psPfETTcw',
#      'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=txv14QlmLth-_psPfETTcw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "I've been here a couple of times. The space is nice, you order inside and take it to sit outside at picnic tables. I've never had to wait too long to get a...",
#      'rating': 3,
#      'time_created': '2020-01-12 22:10:31',
#      'user': {'id': 'osdeS7I26qJhW2Qz6sJLzQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=osdeS7I26qJhW2Qz6sJLzQ',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/lJIg47oSNALENE5_11RAxA/o.jpg',
#       'name': 'Dave F.'}}],
#    'total': 2795,
#    'possible_languages': ['fr', 'en', 'es', 'pt']}},
#  {'aTXpZudGAKCihlF_zaqBIg': {'reviews': [{'id': 'yRe99Vn4NnVFbVNRueDywQ',
#      'url': 'https://www.yelp.com/biz/f-and-f-pizzeria-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=yRe99Vn4NnVFbVNRueDywQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "$4.36 is the most I've paid for a NYC slice, but it delivered. I had the crust as the first bite, and it was charred perfectly, the right balance of crispy...",
#      'rating': 4,
#      'time_created': '2020-01-12 09:31:22',
#      'user': {'id': '1gpZXnZhfVYkKjWZXA7FzA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=1gpZXnZhfVYkKjWZXA7FzA',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/6qEPOUQbdBJgHHSUmlmS3Q/o.jpg',
#       'name': 'Peter H.'}},
#     {'id': 'oUl7iggiBbwmhJ-iXa3XMw',
#      'url': 'https://www.yelp.com/biz/f-and-f-pizzeria-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=oUl7iggiBbwmhJ-iXa3XMw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Everyone, please, settle down. You'd think this was the second coming of the pizza god.  I ate here before seeing any reviews and now I'm left wondering if...",
#      'rating': 3,
#      'time_created': '2020-01-08 10:00:15',
#      'user': {'id': 'En475QOepLcRDEYS3s82SQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=En475QOepLcRDEYS3s82SQ',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/qaSdaIKWkPmuDD6os-L25Q/o.jpg',
#       'name': 'Alex L.'}},
#     {'id': '4M0moEqOttuJrzXLGULj1w',
#      'url': 'https://www.yelp.com/biz/f-and-f-pizzeria-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=4M0moEqOttuJrzXLGULj1w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "I had high hopes for this place, but was let down. Thankfully, there wasn't a line when I arrived during the dinner rush on a Saturday afternoon, otherwise...",
#      'rating': 3,
#      'time_created': '2019-11-23 18:21:24',
#      'user': {'id': 'fh_8Hjo4xw9fp3hFcqnC_g',
#       'profile_url': 'https://www.yelp.com/user_details?userid=fh_8Hjo4xw9fp3hFcqnC_g',
#       'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/W1uJLg2q6Y53D3thirFU_g/o.jpg',
#       'name': 'Julia F.'}}],
#    'total': 71,
#    'possible_languages': ['en']}},
#  {'LF1QAuvpfX7KGQlg2zMg6Q': {'reviews': [{'id': 'srmGg6-EvGEgyoDZeU405A',
#      'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=srmGg6-EvGEgyoDZeU405A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "I spent the following few days after eating at John's just dreaming of the next time I could go back. John's of Bleecker's standard pie has everything I...",
#      'rating': 5,
#      'time_created': '2020-01-10 14:04:12',
#      'user': {'id': 'UbuOU1WjHBVIzqx2wxWH8Q',
#       'profile_url': 'https://www.yelp.com/user_details?userid=UbuOU1WjHBVIzqx2wxWH8Q',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/xj8keWS9KE5SSUr43z8UpQ/o.jpg',
#       'name': 'Isabelle W.'}},
#     {'id': 'oEIUEgMBZqsgyhOlowHhKA',
#      'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=oEIUEgMBZqsgyhOlowHhKA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'This was our second pizza stop of the night (we split a slice at the first stop). \n\nThere was a line out the door when we got there on a Friday night, but...',
#      'rating': 4,
#      'time_created': '2020-01-20 06:37:43',
#      'user': {'id': 'QGOtNZfasBwWCuawKjypYA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=QGOtNZfasBwWCuawKjypYA',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/-mfiJS-obVFrxo6Sq9679A/o.jpg',
#       'name': 'Jacqueline T.'}},
#     {'id': 'vr5Zy_gsU3tMVdTlN7ZLpQ',
#      'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=vr5Zy_gsU3tMVdTlN7ZLpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'So I came here cause of El Prez. He gave it 9.3 so of course I had to try it. \n\nFood: We ordered a large cheese pizza with extra cheese. I personally think...',
#      'rating': 4,
#      'time_created': '2020-01-18 17:29:48',
#      'user': {'id': 'JMKRGI1r94UXclURaAgMpQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=JMKRGI1r94UXclURaAgMpQ',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/uHla1llirEvHvuWyXricGQ/o.jpg',
#       'name': 'George A.'}}],
#    'total': 1970,
#    'possible_languages': ['fr', 'de', 'en', 'es']}},
#  {'2ggi1luerd3Mf_C82JvCYg': {'reviews': [{'id': 'M7hYOyyHJAgM2YCheBr08w',
#      'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=M7hYOyyHJAgM2YCheBr08w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Yummmm!!!!\n\nGreat service Amman amazing food!\n\nCash only so bring it or use their ATM.',
#      'rating': 5,
#      'time_created': '2020-01-23 16:58:14',
#      'user': {'id': '1vOywRYVJQYeqFdC2zmdOw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=1vOywRYVJQYeqFdC2zmdOw',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/m9bh5tfNR5Vr3wvzdDhzcA/o.jpg',
#       'name': 'Carmen K.'}},
#     {'id': 'KfhgGuUQnyJNds0n2lzmIQ',
#      'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=KfhgGuUQnyJNds0n2lzmIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Grimaldi's pizzeria located in Brooklyn is one of the oldest pizza joints in NYC. Extremely popular amongst tourists and locals, expect a decent 45 mins...",
#      'rating': 3,
#      'time_created': '2019-12-30 00:39:42',
#      'user': {'id': '0gmmH-cgd6jXG2MSXticsw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=0gmmH-cgd6jXG2MSXticsw',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/CiVK4lrQmLyMzOZZTxkHzQ/o.jpg',
#       'name': 'Neerali T.'}},
#     {'id': 'OkMwqrL8wifJsvTQdQR1nw',
#      'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=OkMwqrL8wifJsvTQdQR1nw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "TLDR: It's a little overrated in my opinion. I'd opt for either a dollar slice or another pizza place in New York.\n\nFood: 6/10\nI had a lot of pizza during...",
#      'rating': 3,
#      'time_created': '2019-12-23 17:15:01',
#      'user': {'id': 'yZY3qBVGRlS-m-iEp-Zwdw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=yZY3qBVGRlS-m-iEp-Zwdw',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/8ayQk4_TsN0372gTX1Az6g/o.jpg',
#       'name': 'Felicia L.'}}],
#    'total': 4591,
#    'possible_languages': ['fr', 'en', 'zh', 'pt', 'de', 'it', 'ja', 'es']}},
#  {'tluWdKIinSkg8pOY1qVVeQ': {'reviews': [{'id': 'n2h6QnirylWwEcRa54H_7A',
#      'url': 'https://www.yelp.com/biz/square-pizza-new-york-3?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=n2h6QnirylWwEcRa54H_7A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Came here to get a small slice and found a gem...  they have a great pizza with refried beans in it and it was surprisingly good. Def check them out if I...',
#      'rating': 5,
#      'time_created': '2019-11-23 16:06:06',
#      'user': {'id': 'YaVEbRszqSWrHZalNHVqhQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=YaVEbRszqSWrHZalNHVqhQ',
#       'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/cv1FcvSioEKjC5NQddZgLQ/o.jpg',
#       'name': 'Carlo G.'}},
#     {'id': 'YvnmpUVe7q3iivqXn3Zd1w',
#      'url': 'https://www.yelp.com/biz/square-pizza-new-york-3?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=YvnmpUVe7q3iivqXn3Zd1w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'New to this area and was in search late last night for some pizza. Not just any plain old $1 pizza but for something that was worth my money. Came across...',
#      'rating': 5,
#      'time_created': '2019-11-26 13:22:56',
#      'user': {'id': '8dUd7xIlHjOws079sg_-Ug',
#       'profile_url': 'https://www.yelp.com/user_details?userid=8dUd7xIlHjOws079sg_-Ug',
#       'image_url': None,
#       'name': 'Janelle R.'}}],
#    'total': 2,
#    'possible_languages': ['en']}},
#  {'C8j0q4Ma_S5hBGuAI-aaww': {'reviews': [{'id': '7jmM9lSClsz1x4Im14GO2w',
#      'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=7jmM9lSClsz1x4Im14GO2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'The plain pie is my reference.  Hard to explain...  you have try it for yourself....  sauce, crust and cheese....  all perfect.... flavor is outstanding...',
#      'rating': 5,
#      'time_created': '2020-01-11 11:46:08',
#      'user': {'id': 'xKwXfw7zC0mV6ibeCazA_w',
#       'profile_url': 'https://www.yelp.com/user_details?userid=xKwXfw7zC0mV6ibeCazA_w',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/sEMeH1KSYUwY0A1cweIk8A/o.jpg',
#       'name': 'Oliver S.'}},
#     {'id': 'hV7otPv2oHyfoxanEVA71A',
#      'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=hV7otPv2oHyfoxanEVA71A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'My gf lives in Brooklyn and said growing up this was the best pizza around.  So I went to the restaurant to see what the hype was about.  I ordered a square...',
#      'rating': 2,
#      'time_created': '2020-01-20 11:51:01',
#      'user': {'id': 'OQSdKscahQlhyxZ5Xa_WbQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=OQSdKscahQlhyxZ5Xa_WbQ',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/Gl16gEg735ow2ldecEiEbQ/o.jpg',
#       'name': 'Jim L.'}},
#     {'id': 'jiLh-jieo6FKA_sEK9L90A',
#      'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=jiLh-jieo6FKA_sEK9L90A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'We tried 6 different NY pizzas in 1.5 days. The Di Fara slice was hands down our winner!\n\nIt was a long trek to get down to the restaurant (about a 40 min...',
#      'rating': 5,
#      'time_created': '2020-01-06 23:59:28',
#      'user': {'id': 'skKshOyHn_Sqy4a-dcKdSg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=skKshOyHn_Sqy4a-dcKdSg',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/-GSM_JslzNVvYZG4Cdn-kg/o.jpg',
#       'name': 'Rachel C.'}}],
#    'total': 3402,
#    'possible_languages': ['en', 'nl', 'it', 'ja']}},
#  {'Q9F2ocrmYuGt1yn3M7MOBw': {'reviews': [{'id': 'Q_TCPu_N5NP9IVds9tFPIQ',
#      'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=Q_TCPu_N5NP9IVds9tFPIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'After watching the famous Thrillist pizza video series "this is not a pizza" by Mark Iacono, a famous Brooklynite and the owner of Lucali and the pizza...',
#      'rating': 5,
#      'time_created': '2020-01-11 12:52:55',
#      'user': {'id': 'oYBUPV6D0aqWCfcQD66sdA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=oYBUPV6D0aqWCfcQD66sdA',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/1IMM2zc1J7IbtITgkwT27w/o.jpg',
#       'name': 'William C.'}},
#     {'id': 'cGSSNa5tNb4Oi1Ury2j2lw',
#      'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=cGSSNa5tNb4Oi1Ury2j2lw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "I don't like leaving scathing reviews, and this is in fact my first one -- but I was compelled to say something, as this is by far one of the most strangely...",
#      'rating': 2,
#      'time_created': '2020-01-23 20:30:43',
#      'user': {'id': 'BlxRcTjVkvunn1Eu_8_4qA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=BlxRcTjVkvunn1Eu_8_4qA',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/w5us8QSSwh6ctwu78Ibsig/o.jpg',
#       'name': 'Jacob M.'}},
#     {'id': 't8AWBfPm01JW1IMZC0dwOw',
#      'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=t8AWBfPm01JW1IMZC0dwOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "This place has been on my list since my brother-in-law's girlfriend suggested it years ago. She's a big pizza fan so we always look to her for the best pies...",
#      'rating': 4,
#      'time_created': '2020-01-23 09:33:53',
#      'user': {'id': 'P5na1Eqyxp-tlf_eSt7a-g',
#       'profile_url': 'https://www.yelp.com/user_details?userid=P5na1Eqyxp-tlf_eSt7a-g',
#       'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/vCTXK2GbxAlNPTz00pMtIw/o.jpg',
#       'name': 'Sara D.'}}],
#    'total': 1496,
#    'possible_languages': ['fr', 'en', 'ja']}},
#  {'hGksyTiHBBdrhbiVjXzWVw': {'reviews': [{'id': 'ZlYAMAodKAi91QoeOMdeMw',
#      'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=ZlYAMAodKAi91QoeOMdeMw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'TL;DR\n. The benchmark for which I will measure all NYC-style pizza\n. The restaurant was cozy; limited seating\n. Crispy crust, freshly made, perfectly...',
#      'rating': 5,
#      'time_created': '2020-01-20 07:12:12',
#      'user': {'id': '3izGBBG0TnKIDUUSiMf4RQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=3izGBBG0TnKIDUUSiMf4RQ',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/0UcAK3fz2hLoMfSh_fXiqg/o.jpg',
#       'name': 'Toshiro W.'}},
#     {'id': 'ZMDXhVAEzzodCEvcQkEZbg',
#      'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=ZMDXhVAEzzodCEvcQkEZbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "When I think of New York Pizza, this is exactly what I want. \n\nIt's a tiny hole in the wall. It's so small, that you can barely walk through it and about 5...",
#      'rating': 5,
#      'time_created': '2020-01-20 06:13:22',
#      'user': {'id': 'QGOtNZfasBwWCuawKjypYA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=QGOtNZfasBwWCuawKjypYA',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/-mfiJS-obVFrxo6Sq9679A/o.jpg',
#       'name': 'Jacqueline T.'}},
#     {'id': '-8Be7OD0od3b1l9gegjq9A',
#      'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=-8Be7OD0od3b1l9gegjq9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Hands down, my favorite thin crust pizza place IN THE WORLD. The slices here are so amazing that I'm torn between not wanting people to know about this...",
#      'rating': 5,
#      'time_created': '2020-01-15 10:36:34',
#      'user': {'id': 'bcW7lGw4AlYLFdVROeGcJQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=bcW7lGw4AlYLFdVROeGcJQ',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/zyWyTYzUIflgcJa2vCx4wA/o.jpg',
#       'name': 'Jennifer C.'}}],
#    'total': 363,
#    'possible_languages': ['en', 'ja']}},
#  {'BgGz5IdV53bGb4o7opR5zg': {'reviews': [{'id': '74zD-MjqKgVtzFZf2AmmQw',
#      'url': 'https://www.yelp.com/biz/arturos-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=74zD-MjqKgVtzFZf2AmmQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'I love coal-oven pizza and it is fantastic here. Also, they use the coal-oven for other doughy delights on the menu. As they say, their bread is like crack....',
#      'rating': 5,
#      'time_created': '2019-12-19 13:27:36',
#      'user': {'id': 'hbQWTNGAVw-PecnJVt8nug',
#       'profile_url': 'https://www.yelp.com/user_details?userid=hbQWTNGAVw-PecnJVt8nug',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/TfkFhVLELWhY6BLSDInigw/o.jpg',
#       'name': 'HarlemLarry G.'}},
#     {'id': 'bnyhqQMb_zUi08GNxXszzw',
#      'url': 'https://www.yelp.com/biz/arturos-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=bnyhqQMb_zUi08GNxXszzw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Went here on a Saturday evening so I expected it to be busy! My friend's dad recommended it to us for trying New York style pizza. We checked in with the...",
#      'rating': 2,
#      'time_created': '2020-01-16 06:48:26',
#      'user': {'id': 'b4YWbiq0UTw6LItN9izADA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=b4YWbiq0UTw6LItN9izADA',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/rNVIPzYxyoBotjekpUTq0g/o.jpg',
#       'name': 'Shelby S.'}},
#     {'id': 'I1IzSFARCfehzcUgXxABRA',
#      'url': 'https://www.yelp.com/biz/arturos-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=I1IzSFARCfehzcUgXxABRA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "The atmosphere was amazing, and the place was packed. A friend and  I went during the jazz festival. \n\nThe food was just average, I wasn't wowed by the...",
#      'rating': 3,
#      'time_created': '2020-01-15 05:56:21',
#      'user': {'id': '-O8cgKRdnB10UxiaL-J0cA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=-O8cgKRdnB10UxiaL-J0cA',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/yV-1PZh3JoPmx7F5mQ_vGA/o.jpg',
#       'name': 'EunSung K.'}}],
#    'total': 674,
#    'possible_languages': ['fr', 'de', 'en', 'es']}},
#  {'4h4Tuuc56YPO6lWfZ1bdSQ': {'reviews': [{'id': '3HK3Yh3QIwGhzKxW4bQqjQ',
#      'url': 'https://www.yelp.com/biz/joes-pizza-new-york-152?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=3HK3Yh3QIwGhzKxW4bQqjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'My favorite pizza place in NYC! Or maybe it is because before moving to NYC, I was just a tourist who wanted NY pizza and it was love at first bite at this...',
#      'rating': 5,
#      'time_created': '2020-01-13 15:22:38',
#      'user': {'id': '3qtfT38sWfTAGQcHgYk3Sg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=3qtfT38sWfTAGQcHgYk3Sg',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/rKcC9pPtBCMMTVPx9QvUUw/o.jpg',
#       'name': 'Ciara M.'}},
#     {'id': 'STt84WzcF1UNNmtHnWeTFA',
#      'url': 'https://www.yelp.com/biz/joes-pizza-new-york-152?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=STt84WzcF1UNNmtHnWeTFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Joe's pizza is one of the most famous spots in NYC. The main location near Times Square almost always has a line of at least 20-30 people going all the way...",
#      'rating': 5,
#      'time_created': '2020-01-08 20:45:25',
#      'user': {'id': 'hkEaFuh40UPF6crjKX2GBg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=hkEaFuh40UPF6crjKX2GBg',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/W3YtVuZ4xqf90CZqH-CoUA/o.jpg',
#       'name': 'Michael S.'}},
#     {'id': 'DewUg2szwAstmYYH95nggg',
#      'url': 'https://www.yelp.com/biz/joes-pizza-new-york-152?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=DewUg2szwAstmYYH95nggg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'There are so many pizza spots so it was tough to decide, we hit up a few apps to see which pizza joints were closest to us at World Trade Center...',
#      'rating': 3,
#      'time_created': '2019-12-31 07:34:51',
#      'user': {'id': 'iNIxjH-qoi0DW-0M2ML2DA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=iNIxjH-qoi0DW-0M2ML2DA',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/dNvxID_NNmqcNv-IKUOjNA/o.jpg',
#       'name': 'Willy M.'}}],
#    'total': 171,
#    'possible_languages': ['fr', 'en', 'ja', 'es']}},
#  {'yH6t1JWcwkdWG4CS5KPvow': {'reviews': [{'id': 'OGpWqzxsfSh-aQRy7JE5EA',
#      'url': 'https://www.yelp.com/biz/adriennes-pizzabar-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=OGpWqzxsfSh-aQRy7JE5EA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "This place has become my favorite date spot. My girl and I come when ever she's able to meet me after work for dinner. The pasta is creamy and the portion...",
#      'rating': 4,
#      'time_created': '2019-12-24 11:15:09',
#      'user': {'id': 'ceig3NSTJFV81_FwJiKRtw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=ceig3NSTJFV81_FwJiKRtw',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/lPMIp3C66Uj7P2jUnGxG6w/o.jpg',
#       'name': 'Cathia L.'}},
#     {'id': 'RZ4V7rLGpbgT9ojfuufueg',
#      'url': 'https://www.yelp.com/biz/adriennes-pizzabar-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=RZ4V7rLGpbgT9ojfuufueg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "I've been coming to Adrienne's for over a decade, and I can tell you it's worth the hype.\n\nThe last time I came here, I brought my wife for her birthday as...",
#      'rating': 5,
#      'time_created': '2019-12-23 12:47:08',
#      'user': {'id': 'HVVcgv9Qx5It0VwY_Kp_xg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=HVVcgv9Qx5It0VwY_Kp_xg',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/Hlu5krZlJhZ43x5dc3cCbA/o.jpg',
#       'name': 'Robert C.'}},
#     {'id': 'UgPNT_vi_7-aApMxYJugaA',
#      'url': 'https://www.yelp.com/biz/adriennes-pizzabar-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=UgPNT_vi_7-aApMxYJugaA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'This is a pretty good pizza joint in the Financial District. Came here with some friends from out of town and we were all equally happy with our meal.\n\nThe...',
#      'rating': 4,
#      'time_created': '2019-12-12 14:26:33',
#      'user': {'id': 'HIvqN4juxVAnEQCAcNyMIA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=HIvqN4juxVAnEQCAcNyMIA',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/nBcexeGVafnONmuE4cp6CA/o.jpg',
#       'name': 'Melville G.'}}],
#    'total': 1642,
#    'possible_languages': ['fr', 'en', 'zh', 'nb', 'de', 'nl', 'es']}},
#  {'pGr5QuQU7Ur5GHLvXbT8bw': {'reviews': [{'id': 'LcPEm77TZW-DTqLY1P6W8A',
#      'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=LcPEm77TZW-DTqLY1P6W8A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'The vegan pizza options were amazing! And much appreciated! \n\nThe atmosphere was cozy and inviting. The pizza and wine made it even better! \n\nWe will be...',
#      'rating': 5,
#      'time_created': '2019-11-05 06:24:58',
#      'user': {'id': 'u2hnG7a70QVmwbTfvasZLw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=u2hnG7a70QVmwbTfvasZLw',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/B5gzPqpAoaVR7fAFG3DrEw/o.jpg',
#       'name': 'Jennifer B.'}},
#     {'id': '0ieKTIoQQdMASKg1hy692w',
#      'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=0ieKTIoQQdMASKg1hy692w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Hey. This place is overhyped. 1. The service was very subpar, almost rude, and very unfriendly. When pizzas were brought to our table we literally were...',
#      'rating': 1,
#      'time_created': '2020-01-10 21:11:23',
#      'user': {'id': 'IeYsK8mrZ7lcFyvG_dRUwQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=IeYsK8mrZ7lcFyvG_dRUwQ',
# ...
#      'text': 'Clean, quaint, and cost effective are some of the words I would choose to describe this pizza joint. Not much else to mention besides the great customer...',
#      'rating': 4,
#      'time_created': '2019-09-23 21:11:33',
#      'user': {'id': 'dZXGoy9qjVFn128z8DSdOQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=dZXGoy9qjVFn128z8DSdOQ',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/d3i_CM24Q1aZ_I37vT70yA/o.jpg',
#       'name': 'Dina M.'}},
#     {'id': '71VHXUCU030W4KNSehKjlw',
#      'url': 'https://www.yelp.com/biz/caruso-pizzeria-and-restaurant-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=71VHXUCU030W4KNSehKjlw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "I was really craving pizza so I went here after my morning bike ride.\n\nThey asked if I wanted sesame seeds on the crust and I said yes and I'm glad I did,...",
#      'rating': 3,
#      'time_created': '2019-07-16 11:35:35',
#      'user': {'id': 'I5TpZRfL3Avy0ggf9eny6A',
#       'profile_url': 'https://www.yelp.com/user_details?userid=I5TpZRfL3Avy0ggf9eny6A',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/ceGb3nZKveuJ3PqeVYPyDw/o.jpg',
#       'name': 'Jenn Y.'}},
#     {'id': '5_GZFRp_xKzStmR2LNO3uQ',
#      'url': 'https://www.yelp.com/biz/caruso-pizzeria-and-restaurant-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=5_GZFRp_xKzStmR2LNO3uQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Pizza was really well done. Crispy crust, just the right amount of cheese. Would recommend. I also got zeppolis they were good as well (ive had better tho...',
#      'rating': 4,
#      'time_created': '2019-06-21 11:21:51',
#      'user': {'id': 'D862q7dCCqTEPce8_eakSg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=D862q7dCCqTEPce8_eakSg',
#       'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/mIOT3rbHDCTYTanB12Eqjg/o.jpg',
#       'name': 'Ciara O.'}}],
#    'total': 65,
#    'possible_languages': ['en']}},
#  {'ESo8Hm27TFi6U3kBzHKeIg': {'reviews': [{'id': '9UUrTJj5jKsfo8KzrkRC6w',
#      'url': 'https://www.yelp.com/biz/pizza-den-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=9UUrTJj5jKsfo8KzrkRC6w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Unassuming little place with top shelf pizza. I've eaten here many times and it never fails.\nFantastic crust and sauces with just the right amount of garlic.",
#      'rating': 5,
#      'time_created': '2019-07-27 07:30:12',
#      'user': {'id': 'cQu6srIu8DCTr8wtffpP7Q',
#       'profile_url': 'https://www.yelp.com/user_details?userid=cQu6srIu8DCTr8wtffpP7Q',
#       'image_url': None,
#       'name': 'T B.'}},
#     {'id': 'jNyZVRbCohegCmgBj_fO8Q',
#      'url': 'https://www.yelp.com/biz/pizza-den-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=jNyZVRbCohegCmgBj_fO8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "I grew up with Pizza Den. I moved out of Brooklyn 7 years ago.\n\nIt's typical Pizza place...  nothing fancy. It's a good pizza shop to grab and go. It's...",
#      'rating': 2,
#      'time_created': '2019-03-27 17:43:30',
#      'user': {'id': 'WysTlXT_iDIAY60Ape6rmg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=WysTlXT_iDIAY60Ape6rmg',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/XRTRvimjokHcEc498SM-dw/o.jpg',
#       'name': 'Nat P.'}},
#     {'id': 'HXif_IsZap13r8R-yj4JDw',
#      'url': 'https://www.yelp.com/biz/pizza-den-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=HXif_IsZap13r8R-yj4JDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Right off D train is this conveniently located pizza joint. I love a good classic slice of NY pizza but this was not it. The guy took 10 seconds to heat up...',
#      'rating': 2,
#      'time_created': '2019-03-15 09:18:05',
#      'user': {'id': 'D1dyxaYtdQbAA77u3Mv3Xw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=D1dyxaYtdQbAA77u3Mv3Xw',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/0OFe8cR09WqMu2aQ4bIcYw/o.jpg',
#       'name': 'Florence V.'}}],
#    'total': 100,
#    'possible_languages': ['en']}},
#  {'QPFxwkDYbc55C-nWQm36FA': {'reviews': [{'id': 'e-h5hMiILw4-oKNL2TugUQ',
#      'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-12?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=e-h5hMiILw4-oKNL2TugUQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': '9 bux for a whole pizza what a bargain been there about 3 times so far and so good will be returning with out a doubt',
#      'rating': 4,
#      'time_created': '2019-12-29 17:38:52',
#      'user': {'id': 'bTSHPAdKk3Qe2FBkKyUpTQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=bTSHPAdKk3Qe2FBkKyUpTQ',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/tTawrJN_s6VjZmlUzEt1zA/o.jpg',
#       'name': 'Matthew W.'}},
#     {'id': 'd2ToeqDR95LuEN-LBnED8Q',
#      'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-12?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=d2ToeqDR95LuEN-LBnED8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "There's a fine line between being thrifty and economical, and just being straight up sketchy...\n\nDuring my most recent visit, I got 2 regular cheese slices,...",
#      'rating': 2,
#      'time_created': '2019-11-26 08:33:36',
#      'user': {'id': 'VLb4iNzbeCmi56Vc-RkyFQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=VLb4iNzbeCmi56Vc-RkyFQ',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/JVIlEvxNYIttIpEOVH9oHQ/o.jpg',
#       'name': 'Alex H.'}},
#     {'id': '1onrqtgaXEcaNavLJ64LMw',
#      'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-12?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=1onrqtgaXEcaNavLJ64LMw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Food is decent for the price. Their slices are overflowing with grease and a bit light in taste, but for $1 a slice you can't be asking for much.\n\nDidn't...",
#      'rating': 2,
#      'time_created': '2019-10-07 11:32:44',
#      'user': {'id': 'wvbV0KfOyRmsuLdTEjgqEA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=wvbV0KfOyRmsuLdTEjgqEA',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/e8RNPsWRfeeu_9o0QwWvSQ/o.jpg',
#       'name': 'Kristin A.'}}],
#    'total': 99,
#    'possible_languages': ['de', 'en', 'es']}},
#  {'-CDfgsM40aA7siEEpR66hw': {'reviews': [{'id': '_LDulgqqGOATEX2eZfY27Q',
#      'url': 'https://www.yelp.com/biz/cafe-daniellos-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=_LDulgqqGOATEX2eZfY27Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Best gluten free pizza. If you want a glue ten free pizza and a fast delivery, this place is the best.',
#      'rating': 5,
#      'time_created': '2019-10-07 17:08:21',
#      'user': {'id': 'ZZLvqS61JkXJE5wdisWjqA',
#       'profile_url': 'https://www.yelp.com/user_details?userid=ZZLvqS61JkXJE5wdisWjqA',
#       'image_url': None,
#       'name': 'david g.'}},
#     {'id': '_r6j1Q5CoxqjTpI6f24GBg',
#      'url': 'https://www.yelp.com/biz/cafe-daniellos-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=_r6j1Q5CoxqjTpI6f24GBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'We absolutely needed a slice of pizza and this place did the trick. A slice of regular and a slice with pepperoni! It totally hit the spot! We were very...',
#      'rating': 3,
#      'time_created': '2020-01-06 16:12:50',
#      'user': {'id': 'FDDI2eWBkZ5BFajPFVW-Zw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=FDDI2eWBkZ5BFajPFVW-Zw',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/mn9bnSw9PQ-cPXgIEzcG3g/o.jpg',
#       'name': 'Betsy S.'}},
#     {'id': 'VJzbSMZv573rs6DQJT2-Bw',
#      'url': 'https://www.yelp.com/biz/cafe-daniellos-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=VJzbSMZv573rs6DQJT2-Bw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "We've ordered delivery from this place a few times.  The food is fine but overpriced for the portions you receive in my view.  $18 for a plate of gnocchi...",
#      'rating': 2,
#      'time_created': '2019-12-21 16:14:42',
#      'user': {'id': 'Sz-FsPuWlDhuJsdORjWADQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=Sz-FsPuWlDhuJsdORjWADQ',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/92bG8qAOUIP8Tq_F5B3new/o.jpg',
#       'name': 'Paul S.'}}],
#    'total': 103,
#    'possible_languages': ['en']}},
#  {'JmDZuDrYrtEKKVr0PypSVA': {'reviews': [{'id': 'egKZizAAFRnQp-xalnDYCA',
#      'url': 'https://www.yelp.com/biz/lennys-pizza-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=egKZizAAFRnQp-xalnDYCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'My go to pizza place in Bensonhurst. Pizzas are fresh and delicious. Counter service are always pleasant and fast.',
#      'rating': 4,
#      'time_created': '2019-12-10 07:32:15',
#      'user': {'id': '7q-97OVYfKGtJMZScsme_g',
#       'profile_url': 'https://www.yelp.com/user_details?userid=7q-97OVYfKGtJMZScsme_g',
#       'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/chi5WIZhDVxvPB1MThni5g/o.jpg',
#       'name': 'Xiao S.'}},
#     {'id': '4tGT0crMBqqyuthIOYYCng',
#      'url': 'https://www.yelp.com/biz/lennys-pizza-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=4tGT0crMBqqyuthIOYYCng&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'One star for this place is extremely generous. Unfortunately, I cannot give negative stars. If you enjoy sauceless, cheeseless, bland,  cardboard pizza,...',
#      'rating': 1,
#      'time_created': '2019-11-03 11:56:00',
#      'user': {'id': '4GsXGoeVhLyIJRVLjNCGQw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=4GsXGoeVhLyIJRVLjNCGQw',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/AI0fKfvvo7-206iQ5QdCng/o.jpg',
#       'name': 'Frank N.'}},
#     {'id': '8VLUlKU3xGfbQZGFsGmM6Q',
#      'url': 'https://www.yelp.com/biz/lennys-pizza-brooklyn?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=8VLUlKU3xGfbQZGFsGmM6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': '"There are ways of killing yourself without killing yourself."  That scene.  When a distraught Bobby C. drops to his death from the Verrazano...  I think...',
#      'rating': 3,
#      'time_created': '2018-10-28 17:33:40',
#      'user': {'id': 'PUDYBk_OW3dYQFNhGPaRjQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=PUDYBk_OW3dYQFNhGPaRjQ',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/L-3lOa9VcWujSh2ZPfRASA/o.jpg',
#       'name': 'Yael D.'}}],
#    'total': 149,
#    'possible_languages': ['en', 'it']}},
#  {'h37t9rA06Sr4EetJjKrfzw': {'reviews': [{'id': 'S4a3sGfNbdl_6vZsAMqTeg',
#      'url': 'https://www.yelp.com/biz/don-angie-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=S4a3sGfNbdl_6vZsAMqTeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': "Returned on NYE and got a walk-in at the bar pretty quickly. Started with the nonna's little nip - excellent - then had the Chinata colada, which I also...",
#      'rating': 5,
#      'time_created': '2020-01-24 07:19:45',
#      'user': {'id': 'HVQKFDi-vZbawtmLMq3ZOw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=HVQKFDi-vZbawtmLMq3ZOw',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/hR3klUhVTFCrNjnUhYb2hA/o.jpg',
#       'name': 'Gab G.'}},
#     {'id': 'Lj3kNIbS-Ekg0dUM2TyrpA',
#      'url': 'https://www.yelp.com/biz/don-angie-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=Lj3kNIbS-Ekg0dUM2TyrpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'I will update this review after I eat my leftovers lol! Got my reservation 30 days out on my phone at 8:59 on Resy. The restaurant is very beautiful. It...',
#      'rating': 3,
#      'time_created': '2020-01-24 07:51:41',
#      'user': {'id': 'eLxD2wEYnxtNvEzCMP1tnQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=eLxD2wEYnxtNvEzCMP1tnQ',
#       'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/IUTqWSovFPP_33ZJrpCiPQ/o.jpg',
#       'name': 'Whitney H.'}},
#     {'id': 'KfI5Kwx8s376hxK4Dd9e5w',
#      'url': 'https://www.yelp.com/biz/don-angie-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=KfI5Kwx8s376hxK4Dd9e5w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'I been wanting to come here for a couple of months after hearing such great things.\nMy husband was able to get reservations for my birthday!\n\nWe arrived...',
#      'rating': 5,
#      'time_created': '2020-01-09 12:29:13',
#      'user': {'id': 'dArzYnlZh0gBLjA6YkJeoQ',
#       'profile_url': 'https://www.yelp.com/user_details?userid=dArzYnlZh0gBLjA6YkJeoQ',
#       'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/GY9CqOYiuOmpAOclhyJnBA/o.jpg',
#       'name': 'Isabel J.'}}],
#    'total': 295,
#    'possible_languages': ['en', 'es']}},
#  {'SQba0_SKF7wypTBAUyrrgA': {'reviews': [{'id': 'xXRu6QidWAJUa2Q9fS8icw',
#      'url': 'https://www.yelp.com/biz/pizza-and-pita-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=xXRu6QidWAJUa2Q9fS8icw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Never a disappointment Pizza and Pita do a great job at the few things they do.  They have a pretty nice selection of halal stuff.  I ordered a combo over...',
#      'rating': 4,
#      'time_created': '2019-12-18 21:12:20',
#      'user': {'id': 'fVcdur3u2KqV0JcA3-Lo6Q',
#       'profile_url': 'https://www.yelp.com/user_details?userid=fVcdur3u2KqV0JcA3-Lo6Q',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/Byz5Fs-uK_Cm7UVCK-BbCw/o.jpg',
#       'name': 'Richard L.'}},
#     {'id': '5X_NImrOj_bLqphmnMqNFw',
#      'url': 'https://www.yelp.com/biz/pizza-and-pita-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=5X_NImrOj_bLqphmnMqNFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Pizza & Pita is a tiny place right near NYU Langone with only a few tables available. I assume that most of the business here is from take-out orders or...',
#      'rating': 2,
#      'time_created': '2019-10-07 14:34:37',
#      'user': {'id': '-xUg8J3X1DWg4f3I6WumHg',
#       'profile_url': 'https://www.yelp.com/user_details?userid=-xUg8J3X1DWg4f3I6WumHg',
#       'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/sXqE3GaW0VXzWq1ybfAMPw/o.jpg',
#       'name': 'Eric K.'}},
#     {'id': '0OOEZ-SuapKBv4-qy2qKbg',
#      'url': 'https://www.yelp.com/biz/pizza-and-pita-new-york?adjust_creative=J9KJPyNDI8wot3aYJNt8tg&hrid=0OOEZ-SuapKBv4-qy2qKbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=J9KJPyNDI8wot3aYJNt8tg',
#      'text': 'Well after the shutdown everything has been really good. \n\nThis my staple pizza goto. Plus it seems like they are open all the time. Ah... they close at...',
#      'rating': 4,
#      'time_created': '2019-08-10 01:14:42',
#      'user': {'id': 'aSHQGf6xQrkJYCJgOXfjUw',
#       'profile_url': 'https://www.yelp.com/user_details?userid=aSHQGf6xQrkJYCJgOXfjUw',
#       'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/xiwWiPsD05AAZ6au0p8J5g/o.jpg',
#       'name': 'Evan R.'}}],
#    'total': 59,
#    'possible_languages': ['en']}}]

# %%
review_data=review.copy()

# %%
len(review_data)
# Out:
# 1000

# %%
type(review_data)
# Out:
# list

# %%
len(review_data)
# Out:
# 1000

# %%
#i:['reviews', 'total', 'possible_languages']
#j:['id', 'url', 'text', 'rating', 'time_created', 'user']

business_id_review_id=[]
for i in range(0,len(review_data)):
        for m in range(0,len(review_data[i][business_id[i]]['reviews'])):
            business_id_review_id.append((business_id[i],review_data[i][business_id[i]]['reviews'][m]['id']))

business_id_R=[]            
for i in business_id_review_id:
    business_id_R.append(i[0])
    
review_id=[]
for i in business_id_review_id:
    review_id.append(i[1])

# %%
for i in review_id:
    if review_id.count(i)>1:
        print(i)
# Out:
# h-zA-hJqIUizUoYDSR1ZZg
# kGWah9C0wzQ6MfmPZbCqmw
# iiDwadSYS6pO5ohIGoeqdg
# h-zA-hJqIUizUoYDSR1ZZg
# kGWah9C0wzQ6MfmPZbCqmw
# iiDwadSYS6pO5ohIGoeqdg
# sna0uM6l3Tq3ua6PSQQqPw
# 2e7vcL027rmOyJ5EsTrN-A
# o3s-ElZP3opvNXId2xnlNA
# sna0uM6l3Tq3ua6PSQQqPw
# 2e7vcL027rmOyJ5EsTrN-A
# o3s-ElZP3opvNXId2xnlNA

# %%
review_id.index('h-zA-hJqIUizUoYDSR1ZZg')
# Out:
# 1193

# %%
review_id.index('kGWah9C0wzQ6MfmPZbCqmw')
# Out:
# 1194

# %%
review_id.index('iiDwadSYS6pO5ohIGoeqdg')
# Out:
# 1195

# %%
review_id.index('sna0uM6l3Tq3ua6PSQQqPw')
# Out:
# 1639

# %%
review_id.index('2e7vcL027rmOyJ5EsTrN-A')
# Out:
# 1640

# %%
review_id.index('o3s-ElZP3opvNXId2xnlNA')
# Out:
# 1641

# %%
len(reviews)
# Out:
# 2968

# %%
# Out:
# ('LNh3AG1S-LHcZv6hUDcVNw',
#  'This is our go to pizzeria for our take out. Service is amazing here. They are very friendly and always make you feel welcome. This is rare at pizzerias...',
#  5,
#  'Annah A.',
#  '8TxtT_qnNxnriCNpzGqJdQ')

# %%
# Out:
# 'm9qzCxMLgv-SUsk_3-HeKQ'

# %%
#review_data--text

text=[]
for i in range(0,len(review_data)):
        for m in range(0,len(review_data[i][business_id[i]]['reviews'])):
            text.append(review_data[i][business_id[i]]['reviews'][m]['text'])
len(text)
# Out:
# 2968

# %%
review_rating=[]
for i in range(0,len(review_data)):
        for m in range(0,len(review_data[i][business_id[i]]['reviews'])):
            review_rating.append(review_data[i][business_id[i]]['reviews'][m]['rating'])
len(review_rating)
# Out:
# 2968

# %%
user=[]
for i in range(0,len(review_data)):
        for m in range(0,len(review_data[i][business_id[i]]['reviews'])):
            user.append(review_data[i][business_id[i]]['reviews'][m]['user'])
            
users=[]            
for i in range(0,len(user)):
    users.append(user[i]['name'])
len(users)
# Out:
# 2968

# %%
####review_data 
# business_id_R
# review_id
# text
# rating 
# user

reviews=[]
for i in range(0,len(review_id)):
     reviews.append((review_id[i],text[i],review_rating[i],users[i],business_id_R[i]))

# %%
reviews.remove(reviews[1193])
reviews.remove(reviews[1194])
reviews.remove(reviews[1195])
reviews.remove(reviews[1639])
reviews.remove(reviews[1640])
reviews.remove(reviews[1641])

# %%
r=[]
for i in range(0,len(reviews)):
    r.append(reviews[i][0])
    if r.count(reviews[i][1])>1:
        print (i)

# %%
# #b_data
# business_id
# name
# review_count
# rating
# street
# state
# zip_code
# country
# price
# phone
business_1=[]
for i in range(0,len(business_id)):
     business_1.append((business_id[i],name[i],price[i],phone[i],review_count[i],rating[i],street[i],
                       state[i],zip_code[i],country[i]))
        

business_1.remove(('P90fQ5WHs381XvgEibs9OQ',
 'J & V Pizzeria',
 1,
 '+17182322700',
 231,
 4.0,
 '6322 18th Ave',
 'NY',
 '11204',
 'US'))
business_1.remove(('Cjg5steonbecyrjYIuHv9A',
 "Arturo's Pizza",
 1,
 '+12122882430',
 127,
 3.5,
 '1610 York Ave',
 'NY',
 '10028',
 'US'))

# %%
len(set(business_1))
# Out:
# 998

# %%
import mysql.connector
from mysql.connector import errorcode

# %%
db_name = 'yelp'

# %%
cnx = mysql.connector.connect(
    host = "my-database.c2zzlugcfplv.us-east-1.rds.amazonaws.com",
    user = "admin",
    passwd = "melaniesoek"
)
cursor=cnx.cursor()

# %%
def create_database(cursor, database):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)

# %%
# check to see if the database already 
try:
    cursor.execute("USE {}".format(db_name))

#if the previous line fails because there isn't a db by that name run this line

except mysql.connector.Error as err:
    print("Database {} does not exists.".format(db_name))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, db_name)
        print("Database {} created successfully.".format(db_name))
        cnx.database = db_name
    else:
        print(err)
        exit(1)

# %%
TABLES = {}
TABLES['Businesses'] = (
    "CREATE TABLE businesses ("
    "  business_id varchar(200) NOT NULL ,"
    "  name varchar(200),"
    "  review_count int(250),"
    "  rating DECIMAL (10,2) ,"
    "  price int(10),"
    "  phone varchar(200),"
    "  street varchar(200),"
    "  city varchar(200),"
    "  zip_code int(5),"
    "  state varchar(200),"
    "  country varchar(200) ,"
    "  PRIMARY KEY (business_id)"
    ")")

# (review_id[i],text[i],review_rating[i],users[i],business_id_R[i])
TABLES['Reviews'] = (
    "CREATE TABLE reviews ("
    "  review_id varchar(100) NOT NULL,"
    "  text varchar(5000) ,"
    "  rating char(4)  ,"
    "  user varchar(14),"
    "  business_id_R varchar(100) ,"
    "  PRIMARY KEY (review_id)"
    ") ENGINE=InnoDB")

# %%
#TABLES['businesses']

# %%
TABLES['Reviews']
# Out:
# 'CREATE TABLE reviews (  review_id varchar(100) NOT NULL,  text varchar(5000) ,  rating char(4)  ,  user varchar(14),  business_id_R varchar(100) ,  PRIMARY KEY (review_id)) ENGINE=InnoDB'

# %%
cnx = mysql.connector.connect(
    host = 'my-database.c2zzlugcfplv.us-east-1.rds.amazonaws.com',
    user = 'admin',
    passwd = 'melaniesoek',
    database = db_name)
cursor = cnx.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-85f8c45dc0ea> in <module>
# ----> 1 cnx = mysql.connector.connect(
#       2     host = 'my-database.c2zzlugcfplv.us-east-1.rds.amazonaws.com',
#       3     user = 'admin',
#       4     passwd = 'melaniesoek',
#       5     database = db_name
#
# NameError: name 'mysql' is not defined

# %%
for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")

cursor.close()
cnx.close()
# Out:
# Creating table Businesses: already exists.
# Creating table Reviews: already exists.

# %% [markdown]
# # INSERT TABLES

# %%
#insert data
reviews1=reviews[0:2]
# business_1
reviews1
# Out:
# [('H4eanmM_xB5MESW0vYWXlQ',
#   'Every time you go by here, there is a line out the door. Dont be fooled as there is nowhere inside to stand inside!  That is the catch right?  Long lines...',
#   5,
#   'Erik H.',
#   'zj8Lq1T8KIC5zwFief15jg'),
#  ('m9qzCxMLgv-SUsk_3-HeKQ',
#   "Probably the best pizza I've ever had. Line is always out the door and down the block. \n\nOne thing you love but may also find disgusting is the pepperoni...",
#   5,
#   'Marquis F.',
#   'zj8Lq1T8KIC5zwFief15jg')]

# %%
cnx = mysql.connector.connect(
    host = 'my-database.c2zzlugcfplv.us-east-1.rds.amazonaws.com',
    user = 'admin',
    passwd = 'melaniesoek',
    database = db_name
)
cur = cnx.cursor()

# %%
stmt_r="INSERT INTO reviews(review_id, text, rating, uesr, business_id_R) VALUES (%s,%s,%s,%s,%s)"

# %%
cur.executemany(stmt_r, reviews1)
cnx.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488                                raw=raw, buffered=buffered,
# --> 489                                raw_as_string=raw_as_string)
#     490         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Lock wait timeout exceeded; try restarting transaction
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-1103-bce5b5002659> in <module>
# ----> 1 cur.executemany(stmt_r, reviews1)
#       2 cnx.commit()
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/cursor_cext.py in executemany(self, operation, seq_params)
#     350             stmt = self._batch_insert(operation, seq_params)
#     351             if stmt is not None:
# --> 352                 return self.execute(stmt)
#     353
#     354         rowcnt = 0
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     264             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     265                                          buffered=self._buffered,
# --> 266                                          raw_as_string=self._raw_as_string)
#     267         except MySQLInterfaceError as exc:
#     268             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     490         except MySQLInterfaceError as exc:
#     491             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
# --> 492                                              sqlstate=exc.sqlstate)
#     493         except AttributeError:
#     494             if self._unix_socket:
#
# DatabaseError: 1205 (HY000): Lock wait timeout exceeded; try restarting transaction

# %%
cursor.close()
cnx.close()

# %%
stmt="INSERT INTO businesses(business_id, name, price, phone, review_count, rating, street, state, zip_code, country) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

# %%
# cursor.executemany(stmt, business_1)
# cnx.commit()

# %%
# reviews
# stmt_r="INSERT INTO reviews(review_id,text,rating,uesr,business_id) VALUES (%s, %s, %s, %s, %s)"

# %%
# stmt_r="INSERT INTO reviews(review_id,text,rating,uesr,business_id) VALUES (%s, %s, %s, %s, %s)"

# %%
# cur.executemany(stmt_r, reviews)
# cnx.commit()

# %% [markdown]
# ## Part 3 - Create ETL pipeline for the business data from the API
#
# Now that you know what data you need from the API, you want to write code that will execute a api call, parse those results and then insert the results into the DB.
#
# It is helpful to break this up into three different functions (*api call, parse results, and insert into DB*) and then you can write a function/script that pull the other three functions together.
#
# Let's first do this for the Business endpoint.

# %%
# Out:
#               business_id                 name  review_count  rating  price  \
# 0  zj8Lq1T8KIC5zwFief15jg  Prince Street Pizza          3395     4.5    1.0
# 1  WIhm0W9197f_rRtDziq5qQ     Lombardi's Pizza          6076     4.0    2.0
#
#           phone         stree      city zip_code state country
# 0  +12129664100  27 Prince St  New York    10012    NY      US
# 1  +12129417994  32 Spring St  New York    10012    NY      US

# %%
# write a function to parse the API response 
# so that you can easily insert the data in to the DB

# %%
# Write a function to take your parsed data and insert it into the DB

# %%
# Write a script that combines the three functions above into a single process.

# %% [markdown]
# ## Part 4 -  Create ETL pipeline for the restaurant review data from the API
#
# You've done this for the Businesses, now you need to do this for reviews. You will follow the same process, but your functions will be specific to reviews.

# %%
# write a SQL query to pull back all of the business ids 
# you will need these ids to pull back the reviews for each restaurant

# %%
# write a function that takes a business id 
# and makes a call to the API for reivews

# %%
# Write a function to parse out the relevant information from the reviews

# %%
# write a function to insert the parsed data into the reviews table

# %%
# combine the functions above into a single script

# %% [markdown]
# ## Part 5 -  Write SQL queries that will answer the questions posed.
#
# Now that your data is in the DB, you can answer the questions. Write SQL querires that will answer the questions. **Do not use Pandas in this lab**

# %%
# create connection

# %%
# execute SQL queries

# %% [markdown]
# # Extra Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***

# %%
def yelp_call(url_params, api_key):
    # your code to make the yelp call
    return data

# %%
def parse_results(results):
    # your code to parse the result to make them easier to insert into the DB
    return parsed_results

# %%
def db_insert(cnx, cursor, parsed results):
    # your code to insert and commit the results
    # I would create the connection and cursor outside of this function and then pass it through

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < num and cur < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    db_insert(parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50

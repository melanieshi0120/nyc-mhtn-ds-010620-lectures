# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data=pd.read_csv('review&business_data.csv' ,error_bad_lines=False)
# Out:
# b'Skipping line 84: expected 17 fields, saw 19\nSkipping line 163: expected 17 fields, saw 20\nSkipping line 190: expected 17 fields, saw 18\nSkipping line 333: expected 17 fields, saw 18\nSkipping line 383: expected 17 fields, saw 20\nSkipping line 481: expected 17 fields, saw 18\nSkipping line 603: expected 17 fields, saw 18\nSkipping line 620: expected 17 fields, saw 18\nSkipping line 772: expected 17 fields, saw 18\nSkipping line 956: expected 17 fields, saw 18\nSkipping line 1004: expected 17 fields, saw 18\n'

# %%
data
# Out:
#                   review_id  \
# 0    --RgY9uwpRpADEdwOMvO9g
# 1    -3el4zvenOqn1S9oW7jbug
# 2    -3g3XHsAI49umEclXeao7Q
# 3    -3RuLxGVg1JBnQOARtnICQ
# 4    -4J-0DCpqdwtJsRy7XM_FQ
# ..                      ...
# 992  FBMfufoozh3S_W8oUG4Xmg
# 993  FBy4mFwMoXpWUcfguCDUtA
# 994  FcAE7cOn7ISYc9tf7EXC3A
# 995  fCbUUvUBN00XDi9gJiLDDw
# 996  Fdtg96hjF5I808IbsPLQAw
#
#                                                   text rating          user  \
# 0    Came here for our New Year's Eve dinner. We we...      5      Laura C.
# 1    STAY AWAY! We unfortunately chose to come here...      1       Jenn S.
# 2    This is my second time eating at Santa Panza a...      4      Carly G.
# 3    2 slices of true NYC pizza & a can of soda for...      5     Jannah G.
# 4    The crust was chewy like a bagel--which New Yo...      4      Isaac A.
# ..                                                 ...    ...           ...
# 992  Okay, before I get started: get the burrata.\n...      4       Cori C.
# 993  Solid spot in the UES for specialty pizza by t...      4     Morgan F.
# 994  Hubby surprised me with a birthday weekend for...      4     Amanda G.
# 995  We order from D'angelos a coupke of times a we...      1  Elizabeth P.
# 996  Cuisine: 7\nService: 7\nDecor: 6\nValue: 6\nOv...      4     Gordon Y.
#
#             time_created           business_id_R             business_id  \
# 0    2020-01-15 06:01:17  MHbxF-ZS918-ZoXKQPBEyg  MHbxF-ZS918-ZoXKQPBEyg
# 1    2020-01-11 17:37:21  rJJiGJx3kfMAxtD7P7okHQ  rJJiGJx3kfMAxtD7P7okHQ
# 2    2020-01-11 07:10:10  eTneVbjPKdo4gD9HfkDGdA  eTneVbjPKdo4gD9HfkDGdA
# 3    2020-01-11 09:14:30  H1YIowHp7SMbpVoOtSEIJg  H1YIowHp7SMbpVoOtSEIJg
# 4    2019-10-09 13:29:44  orvnuNWLuoE3-iEx4Aj8eA  orvnuNWLuoE3-iEx4Aj8eA
# ..                   ...                     ...                     ...
# 992  2019-10-03 11:12:37  j6fSechU9HxzbnK-kjQx1Q  j6fSechU9HxzbnK-kjQx1Q
# 993  2019-10-30 09:21:12  e9dZsLoiGF-p-zQPMhdH4g  e9dZsLoiGF-p-zQPMhdH4g
# 994  2019-08-20 06:49:32  uGMDtii24Pg4-CQ3n0GXPQ  uGMDtii24Pg4-CQ3n0GXPQ
# 995  2019-12-19 17:35:01  cM8Bg5Z3QsPYDFu2aufsCg  cM8Bg5Z3QsPYDFu2aufsCg
# 996  2020-01-22 10:11:34  WE_dce2JKcv-VoFNaqiJ4w  WE_dce2JKcv-VoFNaqiJ4w
#
#                                   name  review_count  rating.1  price  \
# 0                      Sotto Le Stelle         188.0       4.5    2.0
# 1                              Celeste         890.0       3.5    2.0
# 2                          Santa Panza         155.0       4.5    2.0
# 3                         2 Bros Pizza         392.0       4.0    1.0
# 4                        Baker's Pizza         204.0       4.5    1.0
# ..                                 ...           ...       ...    ...
# 992  San Matteo Pizza and Espresso Bar         495.0       4.0    2.0
# 993                      Lunetta Pizza         197.0       3.0    1.0
# 994                       Bodega Pizza         134.0       4.0    2.0
# 995   D'Angelo's Pizzeria & Restaurant         134.0       3.0    1.0
# 996                 Carmine's Pizzeria         434.0       4.0    1.0
#
#             phone             street          city zip_code state country
# 0    +17186852086   4407 Queens Blvd     Sunnyside    11104    NY      US
# 1    +12128744559  502 Amsterdam Ave      New York    10024    NY      US
# 2    +13474139695      1079 Broadway      Brooklyn    11221    NY      US
# 3    +12127044251       31 W 46th St      New York    10036    NY      US
# 4    +12127777477       201 Avenue A      New York    10009    NY      US
# ..            ...                ...           ...      ...   ...     ...
# 992  +12124266943       1739 2nd Ave      New York    10128    NY      US
# 993  +12127588100       1162 1st Ave      New York    10065    NY      US
# 994  +19176757077      4455 Broadway      New York    10040    NY      US
# 995  +17184596074     63-27 108th St  Forest Hills    11375    NY      US
# 996  +17187829659     358 Graham Ave      Brooklyn    11211    NY      US
#
# [997 rows x 17 columns]

# %%
data.columns
# Out:
# Index(['review_id', 'text', 'rating', 'user', 'time_created', 'business_id_R',
#        'business_id', 'name', 'review_count', 'rating.1', 'price', 'phone',
#        'street', 'city', 'zip_code', 'state', 'country'],
#       dtype='object')

# %%
data['length_text']=data['text'].apply(lambda x: len(str(x).split()))
data['length_text']
# Out:
# 0      30
# 1      28
# 2      29
# 3      26
# 4      27
#        ..
# 992    30
# 993    30
# 994    28
# 995    28
# 996    29
# Name: length_text, Length: 997, dtype: int64

# %%
data.isnull().sum()
# Out:
# review_id          0
# text               1
# rating             7
# user               8
# time_created       8
# business_id_R      8
# business_id        8
# name               8
# review_count       8
# rating.1           8
# price            131
# phone             27
# street             9
# city               8
# zip_code           8
# state              8
# country           13
# length_text        0
# dtype: int64

# %%
data2=data.dropna(axis=0).head()

# %%
data2.isnull().sum()
# Out:
# review_id        0
# text             0
# rating           0
# user             0
# time_created     0
# business_id_R    0
# business_id      0
# name             0
# review_count     0
# rating.1         0
# price            0
# phone            0
# street           0
# city             0
# zip_code         0
# state            0
# country          0
# length_text      0
# dtype: int64

# %%
y=data2['rating.1']

# %%
x1=data2[['price','review_count','length_text']]

# %%
# Add a constant. Esentially, we are adding a new column (equal in lenght to x), which consists only of 1s
x = sm.add_constant(x1)

# Fit the model, according to the OLS (ordinary least squares) method with a dependent variable y and an idependent x
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# /Users/yingyuxuan/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               rating.1   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     16.07
# Date:                Sun, 26 Jan 2020   Prob (F-statistic):              0.181
# Time:                        22:19:28   Log-Likelihood:                 7.2265
# No. Observations:                   5   AIC:                            -6.453
# Df Residuals:                       1   BIC:                            -8.015
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            1.5300      3.596      0.426      0.744     -44.156      47.216
# price           -0.2652      0.421     -0.629      0.642      -5.619       5.089
# review_count    -0.0012      0.000     -3.041      0.202      -0.006       0.004
# length_text      0.1259      0.147      0.856      0.549      -1.743       1.995
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.544
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.484
# Skew:                          -0.127   Prob(JB):                        0.785
# Kurtosis:                       1.496   Cond. No.                     2.91e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.91e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
